# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Keep an eye on your API usage. Use https://developers.google.com/maps/reporting/gmp-reporting as reference for how to monitor your usage and billing.
#
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
import time
import json
from pprint import pprint
# %matplotlib inline
from scipy.stats import linregress
from matplotlib import pyplot as plt

# Import API key
import api_keys as api

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
vacation_path = 'city_weather.csv'
vacation_df = pd.read_csv(vacation_path)
vacation_df
# Out:
#      Unnamed: 0            City      Lat       Lng  Max Temp  Humidity  \
# 0             0    Punta Arenas -53.1500  -70.9167     39.20        87
# 1             1       Fairbanks  64.8378 -147.7164     46.40        56
# 2             2           Kapaa  22.0752 -159.3190     78.80        57
# 3             3         Mataura -46.1927  168.8643     62.01        73
# 4             4        Coquimbo -29.9533  -71.3436     59.00        88
# ..          ...             ...      ...       ...       ...       ...
# 533         533         Hualmay -11.0964  -77.6139     66.56        85
# 534         534      Esmeraldas -19.7625  -44.3139     68.00        68
# 535         535          Gayéri  12.6497    0.4931     86.11        26
# 536         536  Pindi Bhattian  31.8978   73.2730     82.72        29
# 537         537          Searcy  35.2506  -91.7363     53.60        87
#
#      Cloudiness  Wind Speed Country        Date
# 0             0       10.36      CL  1618453749
# 1            90        6.91      US  1618453479
# 2            20       16.11      US  1618453749
# 3            38        5.99      NZ  1618453750
# 4            90        1.14      CL  1618453463
# ..          ...         ...     ...         ...
# 533          86        7.09      PE  1618453972
# 534           0       11.50      BR  1618453840
# 535          56        4.83      BF  1618453972
# 536          93       10.13      PK  1618453972
# 537           1        2.01      US  1618453973
#
# [538 rows x 10 columns]

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
# Store 'Lat' and 'Lng' into  locations 
locations = vacation_df[["Lat", "Lng"]].astype(float)

# Convert humidity to float and store
# HINT: be sure to handle NaN values
#vacation_df = vacaton_df.dropna()
humidity_perc = vacation_df.Humidity.astype(float)

# Create a poverty Heatmap layer
fig = gmaps.figure()

heat_layer = gmaps.heatmap_layer(locations, weights=humidity_perc, 
                                 dissipating=False, max_intensity=100,
                                 point_radius = 1)

fig.add_layer(heat_layer)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
vacation_df["Cloudiness"].value_counts()
# Out:
# 100    76
# 0      59
# 20     39
# 75     38
# 90     37
#        ..
# 68      1
# 28      1
# 39      1
# 69      1
# 59      1
# Name: Cloudiness, Length: 91, dtype: int64

# %%
max_temp = 85
min_temp = 75
ideal_vacay_df = vacation_df.loc[(vacation_df["Max Temp"] <= max_temp) & (vacation_df["Max Temp"] >= min_temp) &(vacation_df.Cloudiness <=1) & (vacation_df["Wind Speed"]<=10)]
ideal_vacay_df
# Out:
#      Unnamed: 0            City      Lat       Lng  Max Temp  Humidity  \
# 73           73      Nelson Bay -32.7167  152.1500     75.20        41
# 130         130        Lüderitz -26.6481   15.1594     75.56        28
# 209         209          Ixtapa  20.7000 -105.2000     77.00        78
# 268         268        Flinders -34.5833  150.8552     75.99        42
# 273         273       Iranshahr  27.2025   60.6848     77.00        27
# 295         295       Kavaratti  10.5669   72.6420     83.89        67
# 355         355           Kiama -34.6833  150.8667     75.99        42
# 360         360  Cabo San Lucas  22.8909 -109.9124     84.20        37
# 425         425        Araouane  18.9048   -3.5265     84.04        13
# 444         444     San Lorenzo -25.3333  -57.5333     75.20        88
# 514         514         Malakal   9.5334   31.6605     79.88        12
# 515         515      Oranjemund -28.5500   16.4333     76.24        30
# 519         519           Bilma  18.6853   12.9164     81.39         8
#
#      Cloudiness  Wind Speed Country        Date
# 73            0        5.75      AU  1618453778
# 130           0        6.62     NaN  1618453796
# 209           1        5.75      MX  1618453537
# 268           0        4.00      AU  1618453853
# 273           0        4.61      IR  1618453855
# 295           1        1.03      IN  1618453867
# 355           1        4.00      AU  1618453895
# 360           1        5.75      MX  1618453613
# 425           0        9.91      ML  1618453919
# 444           0        3.44      PY  1618453929
# 514           1        4.94      SS  1618453954
# 515           0        7.27     NaN  1618453954
# 519           0        9.19      NE  1618453963

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
ideal_vacay_df.dropna(inplace=True)
ideal_vacay_df
# Out:
# <ipython-input-6-a2923cc032d4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ideal_vacay_df.dropna(inplace=True)
#      Unnamed: 0            City      Lat       Lng  Max Temp  Humidity  \
# 73           73      Nelson Bay -32.7167  152.1500     75.20        41
# 209         209          Ixtapa  20.7000 -105.2000     77.00        78
# 268         268        Flinders -34.5833  150.8552     75.99        42
# 273         273       Iranshahr  27.2025   60.6848     77.00        27
# 295         295       Kavaratti  10.5669   72.6420     83.89        67
# 355         355           Kiama -34.6833  150.8667     75.99        42
# 360         360  Cabo San Lucas  22.8909 -109.9124     84.20        37
# 425         425        Araouane  18.9048   -3.5265     84.04        13
# 444         444     San Lorenzo -25.3333  -57.5333     75.20        88
# 514         514         Malakal   9.5334   31.6605     79.88        12
# 519         519           Bilma  18.6853   12.9164     81.39         8
#
#      Cloudiness  Wind Speed Country        Date
# 73            0        5.75      AU  1618453778
# 209           1        5.75      MX  1618453537
# 268           0        4.00      AU  1618453853
# 273           0        4.61      IR  1618453855
# 295           1        1.03      IN  1618453867
# 355           1        4.00      AU  1618453895
# 360           1        5.75      MX  1618453613
# 425           0        9.91      ML  1618453919
# 444           0        3.44      PY  1618453929
# 514           1        4.94      SS  1618453954
# 519           0        9.19      NE  1618453963

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
#hotel_name = []
#ideal_vacay_df.insert(9, "Hotel Name", True)
hotel_df = ideal_vacay_df
hotel_df
# Out:
#      Unnamed: 0            City      Lat       Lng  Max Temp  Humidity  \
# 73           73      Nelson Bay -32.7167  152.1500     75.20        41
# 209         209          Ixtapa  20.7000 -105.2000     77.00        78
# 268         268        Flinders -34.5833  150.8552     75.99        42
# 273         273       Iranshahr  27.2025   60.6848     77.00        27
# 295         295       Kavaratti  10.5669   72.6420     83.89        67
# 355         355           Kiama -34.6833  150.8667     75.99        42
# 360         360  Cabo San Lucas  22.8909 -109.9124     84.20        37
# 425         425        Araouane  18.9048   -3.5265     84.04        13
# 444         444     San Lorenzo -25.3333  -57.5333     75.20        88
# 514         514         Malakal   9.5334   31.6605     79.88        12
# 519         519           Bilma  18.6853   12.9164     81.39         8
#
#      Cloudiness  Wind Speed Country        Date
# 73            0        5.75      AU  1618453778
# 209           1        5.75      MX  1618453537
# 268           0        4.00      AU  1618453853
# 273           0        4.61      IR  1618453855
# 295           1        1.03      IN  1618453867
# 355           1        4.00      AU  1618453895
# 360           1        5.75      MX  1618453613
# 425           0        9.91      ML  1618453919
# 444           0        3.44      PY  1618453929
# 514           1        4.94      SS  1618453954
# 519           0        9.19      NE  1618453963

# %%
#cities = ideal_vacay_df.City
lat = hotel_df.Lat
lat
lng = hotel_df.Lng
#lng

# %%
# params dictionary to update each iteration
hotel_name = []

params = {
    "radius": 50000,
    "types": "hotel",
    "keyword": "hotel",
    "key": api.g_key
}

# Use the lat/lng to identify hotels
for index, row in hotel_df.iterrows():
       # get lat, lng from df
    lat = row["Lat"]
    lng = row["Lng"]

    # change location each iteration while leaving original params in place
    params["location"] = f"{lat},{lng}"

    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    
    hotel_search = requests.get(base_url, params=params)
    
    # convert to json
    hotel_search = hotel_search.json()

    print(json.dumps(hotel_search, indent=4, sort_keys=True))
    
    # Since some data may be missing we incorporate a try-except to skip any that are missing a data point.
    try:
        #ideal_vacay_df.loc[index, "Hotel"] = hotel_search["results"][0]["name"]
        #ideal_vacay_df.loc[index, "Airport Address"] = name_address["results"][0]["vicinity"]
        hotel_df.loc[index, "Hotel Rating"] = hotel_search["results"][0]["rating"]
        hotel_name.append(hotel_search["results"][0]["name"])
    except (KeyError, IndexError):
        #print("Missing field/result... skipping.")
        hotel_name.append(np.nan(inplace=True))
# Out:
# {
#     "html_attributions": [],
#     "next_page_token": "ATtYBwIJXMD_4K369VdUC0frlJMP0DHOUE9gBIih9w_Y31izB4RpS5Aqbw5oBZ82RxAyNqPdEcMmx6NU6kPvdQkN9JZZ0sBsfh6irAuh6LbL2pr3VOCdIJ8tgmlcYJu--NOq3KW2fsqq-q2cQNVhNiUhJIT7nED_tMFZwJBaPAeuy0R5yxBe2LfUCvIqMj1rbXhQZV4nuaCQp-576Vnf11VbZJ86THuzcuvxnhMBdmXftYPYTkcLOk7qFOG6BBmSzq9JJX4fBVEI_BngLd-efZqCuqszTgnt3Z6Qj7-jbzLe-PQa_1LzJMlNzB_6iHVTvzftAeZkYNsm2WnqGdUbh7MgAG3bxqo4XWKPU_GhbZi1GnudBOyeh7tocTXSn1oF-WRGkLTO55I9boXAUCgO32fx0ueU9JGyJXBE5wGoBhvlUcflmMWXFl-pqyuA0FTiewk",
#     "results": [
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -32.7197222,
#                     "lng": 152.1358333
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -32.71870502010728,
#                         "lng": 152.1370179798927
#                     },
#                     "southwest": {
#                         "lat": -32.72140467989272,
#                         "lng": 152.1343183201073
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Amarna Luxury Beach Resort - Guest Only",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 526,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/110041994898567876283\">A Google User</a>"
#                     ],
#                     "photo_reference": "ATtYBwLmckjm-8mpHz8onedDz5Reaudi_kBGhYrx3kiv6q9Jwu0VciKZheB8lnzOsNandn0XWcbXXImxdNGKVnsmpBm70889Ar8H4nW4eDGXIHZXbz-9Wf8ZXUTtrYXf4jH9dPpe0BeIDlf5dCF50Dps3vTqKUdToBWTFDmTs0xo0bd26AQD",
#                     "width": 790
#                 }
#             ],
#             "place_id": "ChIJaYhBidmDc2sRn0geJ7sLBfc",
#             "plus_code": {
#                 "compound_code": "74JP+48 Nelson Bay, New South Wales, Australia",
#                 "global_code": "4RVJ74JP+48"
#             },
#             "rating": 4.5,
#             "reference": "ChIJaYhBidmDc2sRn0geJ7sLBfc",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 101,
#             "vicinity": "16 Christmas Bush Ave, Nelson Bay"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -32.7179328,
#                     "lng": 152.1044602
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -32.71658517010727,
#                         "lng": 152.1058086798927
#                     },
#                     "southwest": {
#                         "lat": -32.71928482989272,
#                         "lng": 152.1031090201072
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "The Anchorage Port Stephens Hotel & Spa",
#             "photos": [
#                 {
#                     "height": 3243,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/107950504553396364872\">A Google User</a>"
#                     ],
#                     "photo_reference": "ATtYBwLDvZKrb8WfpO7WOYyTo2C9z2PEtCDUwXLkU8a4N83k8_69ZjETini6KBQHTCjDU5DrbLOQhCskUfMI1hnnI1qintnhErltGO54VZogGLwrm1lAKUnMRvD6vPgzrA0HAX-4Wup5-YY4dQero9UKUrMQgQLxrKD6fNsElJYK4VShJnfK",
#                     "width": 4864
#                 }
#             ],
#             "place_id": "ChIJV-0JSTuCc2sRc77wOlQChy4",
#             "plus_code": {
#                 "compound_code": "74J3+RQ Corlette, New South Wales, Australia",
#                 "global_code": "4RVJ74J3+RQ"
#             },
#             "rating": 4.4,
#             "reference": "ChIJV-0JSTuCc2sRc77wOlQChy4",
#             "scope": "GOOGLE",
#             "types": [
#                 "spa",
#                 "lodging",
#                 "bar",
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 671,
#             "vicinity": "26 Corlette Point Rd, Corlette"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -32.7111973,
#                     "lng": 152.0722165
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -32.70999737010727,
#                         "lng": 152.0734783298927
#                     },
#                     "southwest": {
#                         "lat": -32.71269702989272,
#                         "lng": 152.0707786701072
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Bannisters Port Stephens",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1320,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/111314525883635868954\">A Google User</a>"
#                     ],
#                     "photo_reference": "ATtYBwK4NPz1wFHFJoDPsTIPfsr1ukdbnd5rkr1aUoMFla-BsIS7w3WPMoIljdhGPuFhkDyGBNm4Jr2SCo3wnbhkVQbEMoZzr454NIR6k3knMzu4dALUgti9P5E01fF7_OAHMVM7HWwBD73vVgOEyGshvXMqNDArqfLIydBBoDjmTc5BNL-o",
#                     "width": 1980
#                 }
#             ],
#             "place_id": "ChIJq6pay6d4c2sR7QR5TDqwGRQ",
#             "plus_code": {
#                 "compound_code": "73QC+GV Soldiers Point, New South Wales, Australia",
#                 "global_code": "4RVJ73QC+GV"
#             },
#             "rating": 4.2,
#             "reference": "ChIJq6pay6d4c2sR7QR5TDqwGRQ",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 355,
#             "vicinity": "147 Soldiers Point Rd, Soldiers Point"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -32.9266887,
#                     "lng": 151.777211
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -32.92527732010728,
#                         "lng": 151.7784097298927
#                     },
#                     "southwest": {
#                         "lat": -32.92797697989272,
#                         "lng": 151.7757100701072
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/bar-71.png",
#             "name": "The Lucky Hotel",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 2240,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/116744494077933225641\">YY Yang</a>"
#                     ],
#                     "photo_reference": "ATtYBwLyqwNPC1LAOHoGKu2KF7_x0_JUccqJo-g7XRAUOKyVeEwYUoRMJzo9Ez3TrTWp4JDKIFiM0qpj_QzcIT230j6CBjqfm_ABmoJvjfzNUbP8Elmbr0rKnmqeicm-9xOrGTW82EsHg9y3QqOQ5b3xK86ZviD9sjgaINxumfBf3F0tFbtj",
#                     "width": 3968
#                 }
#             ],
#             "place_id": "ChIJgWbPLGQUc2sRVGApDnrWR6g",
#             "plus_code": {
#                 "compound_code": "3QFG+8V Newcastle, New South Wales, Australia",
#                 "global_code": "4RVH3QFG+8V"
#             },
#             "rating": 4.3,
#             "reference": "ChIJgWbPLGQUc2sRVGApDnrWR6g",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "bar",
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1384,
#             "vicinity": "237 Hunter St, Newcastle"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -32.8871078,
#                     "lng": 151.695755
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -32.88573507010727,
#                         "lng": 151.6969813298927
#                     },
#                     "southwest": {
#                         "lat": -32.88843472989272,
#                         "lng": 151.6942816701073
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "The Shortland Hotel",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 2048,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/105580558248090038109\">A Google User</a>"
#                     ],
#                     "photo_reference": "ATtYBwJnT3JwgUnxSYRhuF3fliXQnZW8upyHe-0FXxgEm9xpXeOdJTJVom5Te8F4moCfwIWS4f6HbTpZel7TiP7WQegEWabbYTPWOMqIwR005HskPflFEwp7hlJ-QpnU9Fhdt1ZxsMi7sb3fkua3COwaEErABvy6J4N9-aV9Am7h8MwAX5M",
#                     "width": 1366
#                 }
#             ],
#             "place_id": "ChIJBfY3J2M_c2sRfveDAgRnJLQ",
#             "plus_code": {
#                 "compound_code": "4M7W+58 Shortland, New South Wales, Australia",
#                 "global_code": "4RVH4M7W+58"
#             },
#             "rating": 4.3,
#             "reference": "ChIJBfY3J2M_c2sRfveDAgRnJLQ",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 62,
#             "vicinity": "269 Sandgate Rd, Shortland"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -32.7184599,
#                     "lng": 152.1687954
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -32.71704122010728,
#                         "lng": 152.1702038798927
#                     },
#                     "southwest": {
#                         "lat": -32.71974087989273,
#                         "lng": 152.1675042201072
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Salt at Shoal Bay | Accommodation",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 3600,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/109867496357387138979\">A Google User</a>"
#                     ],
#                     "photo_reference": "ATtYBwK29LtM8BGBJX4MO7ZqBbI-JywFNTHq38x_C7n9z4mPHOQc1hR2yImKwgzxnNARM0gdB3HEG_j2J_O6lF3PMoWtJjOAxH91-MQhEu0xOyMuMt0l2FVJurQ-HlIevzEOFsFwelW7MTllOtyuxLGpsyTflI7ZFwDkknFcoBE3EAgXIGuN",
#                     "width": 2400
#                 }
#             ],
#             "place_id": "ChIJQ2unslSBc2sR8E3UluXrWxE",
#             "plus_code": {
#                 "compound_code": "75J9+JG Shoal Bay, New South Wales, Australia",
#                 "global_code": "4RVJ75J9+JG"
#             },
#             "rating": 4.8,
#             "reference": "ChIJQ2unslSBc2sR8E3UluXrWxE",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 24,
#             "vicinity": "83 Shoal Bay Rd, Shoal Bay"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -32.92606,
#                     "lng": 151.75949
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -32.92480962010728,
#                         "lng": 151.7607445798927
#                     },
#                     "southwest": {
#                         "lat": -32.92750927989272,
#                         "lng": 151.7580449201072
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Holiday Inn Express Newcastle",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 2500,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/106448166204671828097\">A Google User</a>"
#                     ],
#                     "photo_reference": "ATtYBwLSLuhl9UUpPRiTWs3xxEAx37LbLIjagmp-lN3brVNXSABZ-QdQcr2tc0hNe-Wx8sdksJCL9wkL09686A2dTVY_bgDZOzTBkT65D5_eRL3zk7R4d4-8RN4Z237wvxUo48oVnKpQbpIaVJF_pB0VFhyesBKelf9LJQECwVMaVIm7O1V4",
#                     "width": 4000
#                 }
#             ],
#             "place_id": "ChIJwyskZpwVc2sRpvyAbBei09M",
#             "plus_code": {
#                 "compound_code": "3QF5+HQ Newcastle, New South Wales, Australia",
#                 "global_code": "4RVH3QF5+HQ"
#             },
#             "rating": 4.6,
#             "reference": "ChIJwyskZpwVc2sRpvyAbBei09M",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 289,
#             "vicinity": "514 King St, Newcastle"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -33.1047446,
#                     "lng": 151.6479126
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -33.10355662010728,
#                         "lng": 151.6492300298927
#                     },
#                     "southwest": {
#                         "lat": -33.10625627989272,
#                         "lng": 151.6465303701073
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Caves Coastal Bar and Bungalows",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 775,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/104633249440038953652\">A Google User</a>"
#                     ],
#                     "photo_reference": "ATtYBwIkHdXJ3ozhCHdT80-t6ObCXNi4e2uht6exlJugdkM_wL7Fb6UarGmxtMCktdJBLAo6CReHZ-gARHcSfDaleWLbDzLT1UZxBptzviK8-GxmjlDovcAL7Hvoz-rWcNospKuJkfj8rYlEFJf38DuFEGVybPK5RHWxP7g0cXA_nnWZOSFY",
#                     "width": 1125
#                 }
#             ],
#             "place_id": "ChIJScZN9GQhc2sRQHvinPdStkQ",
#             "plus_code": {
#                 "compound_code": "VJWX+45 Caves Beach, New South Wales, Australia",
#                 "global_code": "4RRHVJWX+45"
#             },
#             "rating": 4.2,
#             "reference": "ChIJScZN9GQhc2sRQHvinPdStkQ",
#             "scope": "GOOGLE",
#             "types": [
#                 "meal_takeaway",
#                 "lodging",
#                 "bar",
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1221,
#             "vicinity": "27 Mawson Cl, Caves Beach"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -32.7208333,
#                     "lng": 152.1436111
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -32.71933122010727,
#                         "lng": 152.1448764298927
#                     },
#                     "southwest": {
#                         "lat": -32.72203087989271,
#                         "lng": 152.1421767701073
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Seabreeze Hotel",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 1365,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/115558264356042977175\">A Google User</a>"
#                     ],
#                     "photo_reference": "ATtYBwJyYHCrMPbZcBvDR89QpRCk0lruaZXmOopz7pxiIgvENuYPFIu4LmjLGiMRgcMkg1miQRxf8h28X0IPXfEQ9H2hd4Es7QJiwllNw_xc0hJGTg5LmfEjHj0kCPEXZ7Or7jk2lSMom9r4FxfoXpc8XSzGg_jhqtZgirkSYmAECjE9NeUY",
#                     "width": 2048
#                 }
#             ],
#             "place_id": "ChIJf1PoQN6Dc2sR0PsoeqTRlts",
#             "plus_code": {
#                 "compound_code": "74HV+MC Nelson Bay, New South Wales, Australia",
#                 "global_code": "4RVJ74HV+MC"
#             },
#             "rating": 3.9,
#             "reference": "ChIJf1PoQN6Dc2sR0PsoeqTRlts",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "bar",
#                 "liquor_store",
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "store",
#                 "establishment"
#             ],
#             "user_ratings_total": 745,
#             "vicinity": "1 Stockton St, Nelson Bay"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -32.9270213,
#                     "lng": 151.783569
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -32.92559047010728,
#                         "lng": 151.7849625298927
#                     },
#                     "southwest": {
#                         "lat": -32.92829012989272,
#                         "lng": 151.7822628701073
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Terminus Apartment Hotel",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 4480,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/101570933017743887915\">A Google User</a>"
#                     ],
#                     "photo_reference": "ATtYBwKXr8sczF_0uDqayRJayXUfcARqpW87X-zeTtue40wpzbeyIzhI0DfpUkSao7mPgp4jjoWqqxOzckwY9BAETSZJ0b--yntyfWdjmSFSdVU_80mnMY3_TvlZrg3yd-dFp3nq0KqxLQSW2pqIfzAr3RzAZ7onwPzosOPZV-GIBVUyt8Be",
#                     "width": 6720
#                 }
#             ],
#             "place_id": "ChIJERbRP3sUc2sRlKJseQkPUtc",
#             "plus_code": {
#                 "compound_code": "3QFM+5C Newcastle, New South Wales, Australia",
#                 "global_code": "4RVH3QFM+5C"
#             },
#             "rating": 4.6,
#             "reference": "ChIJERbRP3sUc2sRlKJseQkPUtc",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 254,
#             "vicinity": "111 Scott St, Newcastle"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -32.9252364,
#                     "lng": 151.7583745
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -32.92371697010727,
#                         "lng": 151.7598093798927
#                     },
#                     "southwest": {
#                         "lat": -32.92641662989272,
#                         "lng": 151.7571097201073
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Quest Newcastle West Apartment Hotel",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 1000,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/115076558325344833487\">A Google User</a>"
#                     ],
#                     "photo_reference": "ATtYBwLHiqRGz4fFSjUH5Qhoa2MbNEoIk12tS8gpOBJYSlnPg_dxyU8_uhxa9xfoj-K-LlWBYgXwv6NvuECY9j51r69_TXA6tEkbkWuyuR-p0Y4Ll5OcVuLMDQsVdYg2JHhHTJkoUyAt7MEZ_g5TAQkKT3ahZ8OhOnyT1WvulrwM_ENAOdF6",
#                     "width": 1500
#                 }
#             ],
#             "place_id": "ChIJ3Rp2kU8Uc2sRXwSj4lYZnCg",
#             "plus_code": {
#                 "compound_code": "3QF5+W8 Newcastle West, New South Wales, Australia",
#                 "global_code": "4RVH3QF5+W8"
#             },
#             "rating": 4.3,
#             "reference": "ChIJ3Rp2kU8Uc2sRXwSj4lYZnCg",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 145,
#             "vicinity": "787 Hunter St, Newcastle West"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -32.7251602,
#                     "lng": 151.6256351
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -32.72371442010728,
#                         "lng": 151.6269759298927
#                     },
#                     "southwest": {
#                         "lat": -32.72641407989272,
#                         "lng": 151.6242762701073
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "The Bronte Boutique Hotel",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1080,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/114177660498299465933\">A Google User</a>"
#                     ],
#                     "photo_reference": "ATtYBwIXbX-z97Ce0cp99dUvhCNuQx0J7YZOq6QH8hfsYKPyCAaw73o5_rVYSILSETMQmPXEn1Ej3krCDGniT2E650RtljO491lF5mPAxtQxw4sMgguN3O7qfexlGmk-JSwFuQw8tozKNYJalUOAGa5fnJC2ejUxaTsT5JB1V5DL_E8wHYE",
#                     "width": 1440
#                 }
#             ],
#             "place_id": "ChIJL4S87plDc2sRL6ryaETYR6c",
#             "plus_code": {
#                 "compound_code": "7JFG+W7 Morpeth, New South Wales, Australia",
#                 "global_code": "4RVH7JFG+W7"
#             },
#             "rating": 4.8,
#             "reference": "ChIJL4S87plDc2sRL6ryaETYR6c",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 55,
#             "vicinity": "145-147 Swan St, Morpeth"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -32.9277002,
#                     "lng": 151.7900007
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -32.92638117010728,
#                         "lng": 151.7912488298927
#                     },
#                     "southwest": {
#                         "lat": -32.92908082989272,
#                         "lng": 151.7885491701073
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Newcastle Beach Hotel",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 2736,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/106527487370149864965\">Keith Griffith</a>"
#                     ],
#                     "photo_reference": "ATtYBwJ_xuKJu-T_2M0xQZLCEzkaTV1615x_dxxVvhQFyo4kTqWQrz_GoWXy-ZhkiXlq_lkrB5sLzdDPejuinwvAdCFXu-GERrVhrY9N1t_QhUxP6pHaUN5_xT_BDnkZ-ley0sDCvTBs1CRANWs4BvH2qbFrtXX2-eIAQlNLP8MFNypvKX2Z",
#                     "width": 3648
#                 }
#             ],
#             "place_id": "ChIJv2fTApUVc2sR96jFaS5n_sA",
#             "plus_code": {
#                 "compound_code": "3QCR+W2 Newcastle East, New South Wales, Australia",
#                 "global_code": "4RVH3QCR+W2"
#             },
#             "rating": 3.3,
#             "reference": "ChIJv2fTApUVc2sR96jFaS5n_sA",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 307,
#             "vicinity": "21 Parnell Pl, Newcastle East"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -32.7234611,
#                     "lng": 152.145401
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -32.72225297010727,
#                         "lng": 152.1468084298927
#                     },
#                     "southwest": {
#                         "lat": -32.72495262989272,
#                         "lng": 152.1441087701073
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Mantra Nelson Bay",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1993,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/111157643042927711426\">Mantra Aqua</a>"
#                     ],
#                     "photo_reference": "ATtYBwJyTlYuRxomPKv-r2rOU3R7AiXCiArW-8hgMkF_00xl2Cz5BUY9FYLGBiM6AfsxWiCpfKTIFUMcxNGpYj5SuMTrDzCDnBjKl2WnhQMhmkvFxIQzt789gdDFOz2t2F5LWJB-CcHxOUGnt5V_FIGVyLpBQrscZVnUUS4ANvacCQoW_ngR",
#                     "width": 3000
#                 }
#             ],
#             "place_id": "ChIJka4PW-eDc2sRmukLrmECmcc",
#             "plus_code": {
#                 "compound_code": "74GW+J5 Nelson Bay, New South Wales, Australia",
#                 "global_code": "4RVJ74GW+J5"
#             },
#             "rating": 4,
#             "reference": "ChIJka4PW-eDc2sRmukLrmECmcc",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 536,
#             "vicinity": "1A Tomaree St, Nelson Bay"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -32.7651555,
#                     "lng": 152.1144042
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -32.76380982010728,
#                         "lng": 152.1157543298927
#                     },
#                     "southwest": {
#                         "lat": -32.76650947989272,
#                         "lng": 152.1130546701072
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/park-71.png",
#             "name": "Port Stephens Koala Sanctuary",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 4000,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/114554895660341962915\">A Google User</a>"
#                     ],
#                     "photo_reference": "ATtYBwJqlLXjEBK9KSjGXDz48CrTpaTJ7O-oTmgXfkrBl8cKPLR6qZL0yqd0gPSXMmKdiQGpUJ_fwweUY_bLUaDWZHfPGe9lg4kp9r5aagPUUIK9ztSDKhBjLhT6KOky8kRRLjC2qBYhBq_UhzA2EQKV_MGnvhqGgBWMy1dJoZjb41AZNFJn",
#                     "width": 6000
#                 }
#             ],
#             "place_id": "ChIJncljgeSCc2sRYDaWnO8zAIU",
#             "plus_code": {
#                 "compound_code": "64M7+WQ One Mile, New South Wales, Australia",
#                 "global_code": "4RVJ64M7+WQ"
#             },
#             "rating": 4.3,
#             "reference": "ChIJncljgeSCc2sRYDaWnO8zAIU",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "park",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 250,
#             "vicinity": "562 Gan Gan Rd, One Mile"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -32.9292042,
#                     "lng": 151.7850517
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -32.92782242010728,
#                         "lng": 151.7864397798928
#                     },
#                     "southwest": {
#                         "lat": -32.93052207989272,
#                         "lng": 151.7837401201073
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Novotel Newcastle Beach",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 683,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/114158478852748337994\">Novotel Newcastle Beach</a>"
#                     ],
#                     "photo_reference": "ATtYBwKkUkJh-AsCZsDL7gfzFnRWGG0cdec5zpid_COiEU1Rm1cMeC8sFWRc7-S0snqR_GRk1q525469aogRXKU_W4y36UJvcFXgNWweK9A1iisdMOEdHa5urE79eqvg0pHDL9UpOe5Di8eIT3_IOJneWjm5zO_LDM29BwWfgukmIQCt_GcC",
#                     "width": 1024
#                 }
#             ],
#             "place_id": "ChIJA5Y9-noUc2sRHmZHqn8E_7Q",
#             "plus_code": {
#                 "compound_code": "3QCP+82 Newcastle, New South Wales, Australia",
#                 "global_code": "4RVH3QCP+82"
#             },
#             "rating": 4.2,
#             "reference": "ChIJA5Y9-noUc2sRHmZHqn8E_7Q",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 515,
#             "vicinity": "5 King St, Newcastle"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -32.7206198,
#                     "lng": 152.1755422
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -32.71925932010728,
#                         "lng": 152.1764829298927
#                     },
#                     "southwest": {
#                         "lat": -32.72195897989273,
#                         "lng": 152.1737832701073
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Ramada Resort by Wyndham Shoal Bay",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 402,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/108050424091858631401\">Ramada Resort Shoal Bay</a>"
#                     ],
#                     "photo_reference": "ATtYBwLIhg8kZVTQVzB8dMaUEtmtH9zsElzME8FaXqhPEIxMa1vpteV0A2fw3wIGxAXdx6eXYxkz3SneCBMPavrL01Uxm4sp0bvLDUW902HINr0jtsinOB7GzcLJlsNjpiQy-y-DHs79405hO8OEIWGovInndE7X9fy6QCrKdiDcOHnJ6J2A",
#                     "width": 715
#                 }
#             ],
#             "place_id": "ChIJI2iSZ1-Bc2sRsYDvPH3lews",
#             "plus_code": {
#                 "compound_code": "75HG+Q6 Shoal Bay, New South Wales, Australia",
#                 "global_code": "4RVJ75HG+Q6"
#             },
#             "rating": 3.9,
#             "reference": "ChIJI2iSZ1-Bc2sRsYDvPH3lews",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 829,
#             "vicinity": "35-45 Shoal Bay Rd, Shoal Bay"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -32.732979,
#                     "lng": 152.109274
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -32.73172707010728,
#                         "lng": 152.1105446798927
#                     },
#                     "southwest": {
#                         "lat": -32.73442672989272,
#                         "lng": 152.1078450201073
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Oaks Pacific Blue Resort",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 385,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/117879997557173573396\">Oaks Pacific Blue Resort</a>"
#                     ],
#                     "photo_reference": "ATtYBwLJYbqyJl0Kel4B2IVSr8UKuE-mshCLb2UssGX_fECwm0_05hTDubFjgE-SWjiFpTeOZSuPMm8ARsRQTnJsuo4VYen-8wBxSyG-0T0qQ-QpnkO3kQf9ngsQbdzb4c7F3hfYaidLxwXmrj0j8c918Jvh59UeYUrTY3n1ZYoOHlqNHZWT",
#                     "width": 800
#                 }
#             ],
#             "place_id": "ChIJ0canQEaCc2sRO8StC5u1_YQ",
#             "plus_code": {
#                 "compound_code": "7485+RP Salamander Bay, New South Wales, Australia",
#                 "global_code": "4RVJ7485+RP"
#             },
#             "rating": 4.1,
#             "reference": "ChIJ0canQEaCc2sRO8StC5u1_YQ",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1210,
#             "vicinity": "265 Sandy Point Rd, Salamander Bay"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -32.929835,
#                     "lng": 151.782534
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -32.92844072010728,
#                         "lng": 151.7838315298927
#                     },
#                     "southwest": {
#                         "lat": -32.93114037989272,
#                         "lng": 151.7811318701073
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "The Grand Hotel",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 1836,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/104432113533530541529\">Keith Blount</a>"
#                     ],
#                     "photo_reference": "ATtYBwIQaWlxoNgpfbSwkM4ymfA6bv0s-DvB-Q56NxhQkd995yMyVoaKE6jEE4YYWFQZ1-an0yBEmMZdrniHz6YnkLzhPa0LlprVQ50Ssb5q3oN8d9iPjY-rM36vB9teyM9JlHKz-X-_gXP1KffP-M9yxezMWfnmPScRkXpg7u_U4wnNHjM9",
#                     "width": 3264
#                 }
#             ],
#             "place_id": "ChIJIey5UmUUc2sRqNg6FEJ4eFo",
#             "plus_code": {
#                 "compound_code": "3QCM+32 Newcastle, New South Wales, Australia",
#                 "global_code": "4RVH3QCM+32"
#             },
#             "rating": 4.2,
#             "reference": "ChIJIey5UmUUc2sRqNg6FEJ4eFo",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 225,
#             "vicinity": "32 Church St, Newcastle"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -32.9286288,
#                     "lng": 151.7881514
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -32.92722602010728,
#                         "lng": 151.7893364798927
#                     },
#                     "southwest": {
#                         "lat": -32.92992567989272,
#                         "lng": 151.7866368201073
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "NOAH'S on the beach",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1108,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/112284596892640312547\">A Google User</a>"
#                     ],
#                     "photo_reference": "ATtYBwJZTEC8p0t4kvXI0OwP-VjcAjMkJ7nXNjx_-uKhmUxXTMh3wxYRTo8xDqFtmytZTMRVNSW4EX5IjAKEnm0SnX2rNidoI0SmD33KARMhGfglcnZ-oIXku0BTE30Dj5MLvEtXWU8NMtko7OLdM7sbX7R1BPunWSLWLIaWG-6yxz3uz-rX",
#                     "width": 2048
#                 }
#             ],
#             "place_id": "ChIJSYIx0nsUc2sRjrSntfc80UE",
#             "plus_code": {
#                 "compound_code": "3QCQ+G7 Newcastle East, New South Wales, Australia",
#                 "global_code": "4RVH3QCQ+G7"
#             },
#             "rating": 4.3,
#             "reference": "ChIJSYIx0nsUc2sRjrSntfc80UE",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "bar",
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 921,
#             "vicinity": "29 Zaara St, Newcastle East"
#         }
#     ],
#     "status": "OK"
# }
# {
#     "html_attributions": [],
#     "results": [
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 20.6418155,
#                     "lng": -105.2355534
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 20.64315162989272,
#                         "lng": -105.2341934701073
#                     },
#                     "southwest": {
#                         "lat": 20.64045197010728,
#                         "lng": -105.2368931298927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Hotel Mio Vallarta",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 3635,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/100997881604263886168\">A Google User</a>"
#                     ],
#                     "photo_reference": "ATtYBwIOtDV5mXLN_9nKzzM6fmZiwdF_BjoYipgMSP7FmTxnSFqGUN7wpCWPlq2_EYwWzXb5wRU4pFDZ-Do2CDmMt9pQS3BhAsDt_KBUEAav-7kRH8gXDyww7A5rOnkPERYmzhYjNC1B4G_C29JBGBbraa4URR7cHm4CI-VPHA-10TzOQ8Gy",
#                     "width": 5452
#                 }
#             ],
#             "place_id": "ChIJdVA8kXZFIYQRF5laZhWGQF4",
#             "plus_code": {
#                 "compound_code": "JQR7+PQ Puerto Vallarta, Jalisco, Mexico",
#                 "global_code": "75GPJQR7+PQ"
#             },
#             "rating": 4.5,
#             "reference": "ChIJdVA8kXZFIYQRF5laZhWGQF4",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 130,
#             "vicinity": "Blvrd Francisco Medina Ascencio 2179-A, Zona Hotelera, Zona Hotelera Nte., Puerto Vallarta"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 20.5875,
#                     "lng": -105.2441667
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 20.58877847989272,
#                         "lng": -105.2427364701073
#                     },
#                     "southwest": {
#                         "lat": 20.58607882010728,
#                         "lng": -105.2454361298927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Hotel Playa Conchas Chinas",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 667,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/103997290424123448301\">A Google User</a>"
#                     ],
#                     "photo_reference": "ATtYBwJABmsPl5A1ItDcSU6mpIryRyPwVvTe6AQWetLg-ueD-Ffs2kKTpqH2GDfWUYP-CojHGu239D5VPXuseocOkF8BkT6PYKP6Zj1tGACdc4lCn2D41PgOybh939gSU1bnoA9Y6cLPZwvXTmouH5cEheAY3JrxGE_KEoiEu2vK5RncPkcn",
#                     "width": 1000
#                 }
#             ],
#             "place_id": "ChIJt2XAiqhPIYQR0r53MgO5jHI",
#             "plus_code": {
#                 "compound_code": "HQQ4+28 Puerto Vallarta, Jalisco, Mexico",
#                 "global_code": "75GPHQQ4+28"
#             },
#             "rating": 4.5,
#             "reference": "ChIJt2XAiqhPIYQR0r53MgO5jHI",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 259,
#             "vicinity": "Carr. Costera a Barra de Navidad Km 2.5, Conchas Chinas, Puerto Vallarta"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 20.6846539,
#                     "lng": -105.2391801
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 20.68608697989272,
#                         "lng": -105.2379150201073
#                     },
#                     "southwest": {
#                         "lat": 20.68338732010728,
#                         "lng": -105.2406146798927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Container Inn Puerto Vallarta",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 554,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/102813024170626812186\">A Google User</a>"
#                     ],
#                     "photo_reference": "ATtYBwKdJnAwbUlslWsfVCNJCt8e_eKJ-mF0gXalbMfcXkMSmWXxDWdFfy4Dgwa9QrKISzjjT9m761Km5pN5G2L62YPCA1NQO6FrElg3GPfh7AjnM-wqZbsg_RK4MH4qK6ImUFfzMK93gNyXCVwJqCTRf1-g3UEgwWhU3nHwTLNd7gwOLYGt",
#                     "width": 800
#                 }
#             ],
#             "place_id": "ChIJsaUFJcdFIYQRCxskKaSRsZY",
#             "plus_code": {
#                 "compound_code": "MQM6+V8 Puerto Vallarta, Jalisco, Mexico",
#                 "global_code": "75GPMQM6+V8"
#             },
#             "rating": 4.2,
#             "reference": "ChIJsaUFJcdFIYQRCxskKaSRsZY",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 543,
#             "vicinity": "Carretera a, Puerto Vallarta - Tepic 4634, Guadalupe Victoria, Puerto Vallarta"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 20.3817975,
#                     "lng": -104.8229014
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 20.38312502989272,
#                         "lng": -104.8216137201073
#                     },
#                     "southwest": {
#                         "lat": 20.38042537010728,
#                         "lng": -104.8243133798927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Francisca Hotel Boutique",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1701,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/114634431870194129151\">A Google User</a>"
#                     ],
#                     "photo_reference": "ATtYBwITgSMM5Qkfx6eOl2xzJ7MUdpVXCZwT4hKmEXWjcWVCiw7EjI6lBhMVhVx4Tzz-9MDdOOag9Gh4jahUZNQ-EJ9VN-SNdciSB5jO4P3NjejdoZ8ZwWk8rmQvojqD2uKzYOB2bTELncgahYO5iEqPjotOWW2qKj2IXOyTQwIDRCG5pu4n",
#                     "width": 2551
#                 }
#             ],
#             "place_id": "ChIJ_8t0EMAcJIQR-cc-H49S9g8",
#             "plus_code": {
#                 "compound_code": "95JG+PR Talpa de Allende, Jalisco, Mexico",
#                 "global_code": "75GQ95JG+PR"
#             },
#             "rating": 4.7,
#             "reference": "ChIJ_8t0EMAcJIQR-cc-H49S9g8",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 30,
#             "vicinity": "Independencia 9 - A, Centro, Talpa de Allende"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 20.6720315,
# ...
#                         "lat": -25.27445852010727,
#                         "lng": -57.59634817010728
#                     },
#                     "southwest": {
#                         "lat": -25.27715817989272,
#                         "lng": -57.59904782989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Le Moustier Suites",
#             "permanently_closed": true,
#             "photos": [
#                 {
#                     "height": 1200,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/112046522609627489704\">CARLOS COCHAN</a>"
#                     ],
#                     "photo_reference": "ATtYBwKL4edIjSIsdjK8kh5yp6W930EICxVlw3_lHNAoIcvngIhYUn3U6F0DEB3aW3lRSFjxGySP1q7NU7UH78v89-IFnUi567kJnEQlbcGFF9mYV5kkdUVj2K-yRGMG97e0uQCWzFjxaOQvJbt8Y6r1Y8J7XFKvERwnxPaHDCzLzff7EHSj",
#                     "width": 1600
#                 }
#             ],
#             "place_id": "ChIJP_x9PzOmXZQRUYxDNwwwA9Y",
#             "plus_code": {
#                 "compound_code": "PCF2+PW Asunci\u00f3n, Paraguay",
#                 "global_code": "5864PCF2+PW"
#             },
#             "rating": 4.4,
#             "reference": "ChIJP_x9PzOmXZQRUYxDNwwwA9Y",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 510,
#             "vicinity": "Nicasio Insaurralde 347, Asunci\u00f3n"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -25.2953879,
#                     "lng": -57.5820629
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -25.29397127010728,
#                         "lng": -57.58067707010727
#                     },
#                     "southwest": {
#                         "lat": -25.29667092989272,
#                         "lng": -57.58337672989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "La Misi\u00f3n Hotel Boutique",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 3767,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/108779595955834513445\">A Google User</a>"
#                     ],
#                     "photo_reference": "ATtYBwIhCpRaQzqjl7-p-VlbuotHCyaM26SPEm8NVwoU0mgGglqpjohxUHYBiWc9wH1gXD1Cn-aPS0LDF9GgqZUdMNJE2bn16P0D5mp2UXK2gioWQCLo2scLU8VoRkuU1RV6xt56t6LjPkHitH4K8J4SLXRkT2Y7WWbK1dYI1uGROcKITPqh",
#                     "width": 5650
#                 }
#             ],
#             "place_id": "ChIJt6lVIpqoXZQRRuf0veF0Oy8",
#             "plus_code": {
#                 "compound_code": "PC39+R5 Asunci\u00f3n, Paraguay",
#                 "global_code": "5864PC39+R5"
#             },
#             "rating": 4.7,
#             "reference": "ChIJt6lVIpqoXZQRRuf0veF0Oy8",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 856,
#             "vicinity": "Dr Juan Eulogio Estigarribia 4990 Esquina, Asunci\u00f3n"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -25.2781204,
#                     "lng": -57.645141
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -25.27674092010728,
#                         "lng": -57.64376757010728
#                     },
#                     "southwest": {
#                         "lat": -25.27944057989272,
#                         "lng": -57.64646722989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Costanera Hotel Asunci\u00f3n",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 3648,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/107822241482891804637\">A Google User</a>"
#                     ],
#                     "photo_reference": "ATtYBwJnws4tqsLS7Op394yIo7TGJ1vcOQOd22UiOhvHEWnGV922AF4u0UrWVzuGYs8LRaeCuROgIh11aviwoO1BG18qqO2UGuqlWr698WIMm6Q8uDfRsPLL3ll4QS6cei-o6pzWcLBXkPB4SHxawA-lZ9mBvvYseRutgbCQ9U7vd6vsKqe-",
#                     "width": 5472
#                 }
#             ],
#             "place_id": "ChIJ10TLYSAIXZQR5AhTSmq_GZA",
#             "plus_code": {
#                 "compound_code": "P9C3+QW Asunci\u00f3n, Paraguay",
#                 "global_code": "5864P9C3+QW"
#             },
#             "rating": 2.6,
#             "reference": "ChIJ10TLYSAIXZQR5AhTSmq_GZA",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 332,
#             "vicinity": "Oliva 1275, Asunci\u00f3n"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -25.2782387,
#                     "lng": -57.55437970000001
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -25.27681212010728,
#                         "lng": -57.55306127010729
#                     },
#                     "southwest": {
#                         "lat": -25.27951177989272,
#                         "lng": -57.55576092989273
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Paramanta Lifestyle Hotel",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 3648,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/110558215335163300049\">A Google User</a>"
#                     ],
#                     "photo_reference": "ATtYBwJ_bAxPINPfqoSgYL1-AN2BxG6AKuk53Ob0hrGJ4EBK2JNCnzKx9RbGwqTi0R2beIFofsP4Aggab2fr7geComlRhJVhUuIhAbaVjWcEnmFsghFnYec0KDzT6qRhnkcU38t3h5UEr-on_OLlsTiZDOqU0ZUyDoGtVT_VNrxpBvGCQ9ZG",
#                     "width": 5472
#                 }
#             ],
#             "place_id": "ChIJEd2vFACmXZQR4AS-TV0cetA",
#             "plus_code": {
#                 "compound_code": "PCCW+P6 Asunci\u00f3n, Paraguay",
#                 "global_code": "5864PCCW+P6"
#             },
#             "rating": 4.3,
#             "reference": "ChIJEd2vFACmXZQR4AS-TV0cetA",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 280,
#             "vicinity": "Avenida Aviadores del Chaco 3198, Asunci\u00f3n"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -25.294086,
#                     "lng": -57.587737
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -25.29273277010728,
#                         "lng": -57.58639402010729
#                     },
#                     "southwest": {
#                         "lat": -25.29543242989272,
#                         "lng": -57.58909367989273
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "La Casona Hotel Boutique",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1080,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/111919157299046952270\">La Casona Hotel Boutique</a>"
#                     ],
#                     "photo_reference": "ATtYBwJQOI4W7bqDk13LRQVckz7-RIgPw3gmrG3U3-4rbMEqwuCTmQkj9X36mF37ujmgV9kDtjqpiIpwG6KqEo5CELHB4tJ5H3G6WejeUdrTLL64CtuYBl09zX5wwHiTXXnuYwKyDPLQ_uu01eMlkbHxC04gwKds1yqGsJFJoAHp1Wr4ruCX",
#                     "width": 1920
#                 }
#             ],
#             "place_id": "ChIJ0Xe2sISoXZQRDcHpHtLzpyE",
#             "plus_code": {
#                 "compound_code": "PC46+9W Asunci\u00f3n, Paraguay",
#                 "global_code": "5864PC46+9W"
#             },
#             "rating": 4.5,
#             "reference": "ChIJ0Xe2sISoXZQRDcHpHtLzpyE",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 90,
#             "vicinity": "General MacArthur 444, Asunci\u00f3n"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -25.2839699,
#                     "lng": -57.6352003
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -25.28252207010728,
#                         "lng": -57.63378262010727
#                     },
#                     "southwest": {
#                         "lat": -25.28522172989273,
#                         "lng": -57.63648227989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Hotel Guaran\u00ed",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 2808,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/102749846499110351272\">A Google User</a>"
#                     ],
#                     "photo_reference": "ATtYBwJ-EAysbAcTvTQb3LOMeU6XR7r_WhhAPWbB1s2mxhJ6npG1J3HLqAY9jMrwMe990hVvMyA7GWCoOhYMm1mny3lrSxoJQOUzG9ESVS2Tm9lx0CZNPvy4ck5rAgldmaBNeS-idWOPiWZhm7ytjXQDREeNVqqL1cr73b_Wmc3v9wToSeKE",
#                     "width": 5032
#                 }
#             ],
#             "place_id": "ChIJFc2Lj_GnXZQRojPZvASnqDY",
#             "plus_code": {
#                 "compound_code": "P987+CW Asunci\u00f3n, Paraguay",
#                 "global_code": "5864P987+CW"
#             },
#             "rating": 4.4,
#             "reference": "ChIJFc2Lj_GnXZQRojPZvASnqDY",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 2182,
#             "vicinity": "Oliva esq, Asunci\u00f3n"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -25.2894526,
#                     "lng": -57.5825389
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -25.28808667010728,
#                         "lng": -57.58122042010728
#                     },
#                     "southwest": {
#                         "lat": -25.29078632989272,
#                         "lng": -57.58392007989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Nino Hotel Boutique",
#             "place_id": "ChIJ76xuMZyoXZQR3QIk7UjJmuQ",
#             "plus_code": {
#                 "compound_code": "PC68+6X Asunci\u00f3n, Paraguay",
#                 "global_code": "5864PC68+6X"
#             },
#             "rating": 5,
#             "reference": "ChIJ76xuMZyoXZQR3QIk7UjJmuQ",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1,
#             "vicinity": "Gral Eugenio Alejandrino Garay 430, Asunci\u00f3n"
#         }
#     ],
#     "status": "OK"
# }
# {
#     "html_attributions": [],
#     "results": [
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 9.515723699999999,
#                     "lng": 31.6559863
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 9.517404679892719,
#                         "lng": 31.65753142989272
#                     },
#                     "southwest": {
#                         "lat": 9.514705020107275,
#                         "lng": 31.65483177010728
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Nile Palace Hotel",
#             "place_id": "ChIJ6TMQvZQy_RYRSWqKBv8Fl-c",
#             "plus_code": {
#                 "compound_code": "GM84+79 Malakal, South Sudan",
#                 "global_code": "6GXHGM84+79"
#             },
#             "rating": 5,
#             "reference": "ChIJ6TMQvZQy_RYRSWqKBv8Fl-c",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 2,
#             "vicinity": "Malakal"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 9.573226,
#                     "lng": 31.67593359999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 9.57456297989272,
#                         "lng": 31.67726222989272
#                     },
#                     "southwest": {
#                         "lat": 9.571863320107276,
#                         "lng": 31.67456257010727
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#             "name": "UNMISS Base Restaurant",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 3096,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/102078157286760728853\">Martin Mouse</a>"
#                     ],
#                     "photo_reference": "ATtYBwKqKVMs0oKWsKhcc4tQhMvrDRki2GVajvqK7v3j-Pi2LG04agYaOEZTsCElJRXzB5oBIj9ZlrXwoG0IxnSxXoOuLFqD6jyO8kgDd1Z58pyjARWEcuyBv8Hd4CftdqbC0zZ_WS-7RVK3K5kOXi8S_mD3nXuFR6-CE99rvdcr1z7J4vvW",
#                     "width": 4128
#                 }
#             ],
#             "place_id": "ChIJpeLaCFUs_RYR-pYeo42BaJ0",
#             "plus_code": {
#                 "compound_code": "HMFG+79 Debalo, South Sudan",
#                 "global_code": "6GXHHMFG+79"
#             },
#             "rating": 3.6,
#             "reference": "ChIJpeLaCFUs_RYR-pYeo42BaJ0",
#             "scope": "GOOGLE",
#             "types": [
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 17,
#             "vicinity": "Debalo"
#         }
#     ],
#     "status": "OK"
# }

# %%
hotel_name
# Out:
# ['Amarna Luxury Beach Resort - Guest Only',
#  'Hotel Mio Vallarta',
#  'Ocean Farm',
#  'هتل خنونه سرزه',
#  'Bangaram Island Resort',
#  'Ocean Farm',
#  'Nobu Hotel Los Cabos',
#  'Factoria Hotel',
#  'Nile Palace Hotel']

# %%
hotel_df["Hotel Name"] = hotel_name
hotel_df.dropna()
hotel_df.to_csv("hotel.csv")
hotel_df
# Out:
# <ipython-input-25-3ad4d2c7d701>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hotel_df["Hotel Name"] = hotel_name
#      Unnamed: 0            City      Lat       Lng  Max Temp  Humidity  \
# 73           73      Nelson Bay -32.7167  152.1500     75.20        41
# 209         209          Ixtapa  20.7000 -105.2000     77.00        78
# 268         268        Flinders -34.5833  150.8552     75.99        42
# 273         273       Iranshahr  27.2025   60.6848     77.00        27
# 295         295       Kavaratti  10.5669   72.6420     83.89        67
# 355         355           Kiama -34.6833  150.8667     75.99        42
# 360         360  Cabo San Lucas  22.8909 -109.9124     84.20        37
# 444         444     San Lorenzo -25.3333  -57.5333     75.20        88
# 514         514         Malakal   9.5334   31.6605     79.88        12
#
#      Cloudiness  Wind Speed Country        Date  Hotel Rating  \
# 73            0        5.75      AU  1618453778           4.5
# 209           1        5.75      MX  1618453537           4.5
# 268           0        4.00      AU  1618453853           5.0
# 273           0        4.61      IR  1618453855           0.0
# 295           1        1.03      IN  1618453867           4.6
# 355           1        4.00      AU  1618453895           5.0
# 360           1        5.75      MX  1618453613           4.7
# 444           0        3.44      PY  1618453929           4.7
# 514           1        4.94      SS  1618453954           5.0
#
#                                   Hotel Name
# 73   Amarna Luxury Beach Resort - Guest Only
# 209                       Hotel Mio Vallarta
# 268                               Ocean Farm
# 273                           هتل خنونه سرزه
# 295                   Bangaram Island Resort
# 355                               Ocean Farm
# 360                     Nobu Hotel Los Cabos
# 444                           Factoria Hotel
# 514                        Nile Palace Hotel

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]].astype(float)

# %%
hotel_df = hotel_df.dropna()
#hotel_rating = hotel_df["Hotel Rating"].astype(float)

# Create a poverty Heatmap layer
fig = gmaps.figure()

heat_layer = gmaps.heatmap_layer(locations, 
                                 dissipating=False, max_intensity=100,
                                 point_radius = 1)

#fig.add_layer(heat_layer)
markers = gmaps.marker_layer(locations)

fig.add_layer(heat_layer)
fig.add_layer(markers)

# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
