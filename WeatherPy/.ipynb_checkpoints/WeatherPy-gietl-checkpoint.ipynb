# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
from scipy.stats import zscore
from scipy.stats import linregress
#from config import api_key

# Import API key
#from api_keys import weather_api_key
import api_keys as api

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy


# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 583

# %%
cities[380]
#api.openweathermap.org/data/2.5/weather?q=jacmel&APPID=7111648151b6cdb2d73c65bb4671e668

#{"coord":{"lon":-72.5347,"lat":18.2342},"weather":[{"id":801,"main":"Clouds","description":"few clouds","icon":"02d"}],
    #"base":"stations","main":{"temp":304.15,"feels_like":307.51,"temp_min":304.15,"temp_max":304.15,"pressure":1015,
        #"humidity":58},"visibility":9000,"wind":{"speed":5.14,"deg":300},"clouds":{"all":20},"dt":1618420578,"sys":{"type":1,"id":7213,"country":"HT","sunrise":1618396431,"sunset":1618441583},"timezone":-14400,"id":3723779,"name":"Jacmel","cod":200}
# Out:
# 'richards bay'

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#Weather key email: Please, use the endpoint api.openweathermap.org for your API calls
#Example of API call:
#api.openweathermap.org/data/2.5/weather?q=London,uk&APPID=7111648151b6cdb2d73c65bb4671e668
url = "http://api.openweathermap.org/data/2.5/weather?"

city_results = []

unique_city = ["goba", "London"]

#enumerate = retrieves item and the position of the item. Index = position, city = name of the item
for index, city in enumerate(cities):
    city_weather_url = "{}q={}&APPID={}&units=imperial".format(url, city, api.weather_api_key)
    #print(city_weather_url)
    #either
    try:
        ##print to see what is available/ where I'm at in the code dev (don't do all the cities pick unique city/(s)). If code is good change back to cities
        print("Processing Record {} of Set {} | {}".format(index, len(cities), city))
        response = requests.get(city_weather_url).json()
        city_results.append(response)
    #or
    except:
        print("{} not found".format(city))

##print(city_results)
len(city_results)
# Out:
# Processing Record 0 of Set 583 | punta arenas
# Processing Record 1 of Set 583 | fairbanks
# Processing Record 2 of Set 583 | kapaa
# Processing Record 3 of Set 583 | mataura
# Processing Record 4 of Set 583 | coquimbo
# Processing Record 5 of Set 583 | canutama
# Processing Record 6 of Set 583 | yellowknife
# Processing Record 7 of Set 583 | ambulu
# Processing Record 8 of Set 583 | clyde river
# Processing Record 9 of Set 583 | upernavik
# Processing Record 10 of Set 583 | verdalsora
# Processing Record 11 of Set 583 | ushuaia
# Processing Record 12 of Set 583 | north myrtle beach
# Processing Record 13 of Set 583 | new norfolk
# Processing Record 14 of Set 583 | ebolowa
# Processing Record 15 of Set 583 | ocampo
# Processing Record 16 of Set 583 | pisco
# Processing Record 17 of Set 583 | paita
# Processing Record 18 of Set 583 | jumla
# Processing Record 19 of Set 583 | bolungarvik
# Processing Record 20 of Set 583 | illoqqortoormiut
# Processing Record 21 of Set 583 | saskylakh
# Processing Record 22 of Set 583 | ribeira grande
# Processing Record 23 of Set 583 | georgetown
# Processing Record 24 of Set 583 | nizhneyansk
# Processing Record 25 of Set 583 | tuktoyaktuk
# Processing Record 26 of Set 583 | busselton
# Processing Record 27 of Set 583 | barabinsk
# Processing Record 28 of Set 583 | albany
# Processing Record 29 of Set 583 | cape town
# Processing Record 30 of Set 583 | hargeysa
# Processing Record 31 of Set 583 | longyearbyen
# Processing Record 32 of Set 583 | pacific grove
# Processing Record 33 of Set 583 | belushya guba
# Processing Record 34 of Set 583 | khatanga
# Processing Record 35 of Set 583 | clifton springs
# Processing Record 36 of Set 583 | palmer
# Processing Record 37 of Set 583 | dawei
# Processing Record 38 of Set 583 | tiksi
# Processing Record 39 of Set 583 | cidreira
# Processing Record 40 of Set 583 | vaini
# Processing Record 41 of Set 583 | hermanus
# Processing Record 42 of Set 583 | tasiilaq
# Processing Record 43 of Set 583 | ilulissat
# Processing Record 44 of Set 583 | avarua
# Processing Record 45 of Set 583 | rikitea
# Processing Record 46 of Set 583 | houma
# Processing Record 47 of Set 583 | goderich
# Processing Record 48 of Set 583 | flin flon
# Processing Record 49 of Set 583 | gurskoye
# Processing Record 50 of Set 583 | norman wells
# Processing Record 51 of Set 583 | bengkulu
# Processing Record 52 of Set 583 | lolua
# Processing Record 53 of Set 583 | pevek
# Processing Record 54 of Set 583 | hasaki
# Processing Record 55 of Set 583 | taolanaro
# Processing Record 56 of Set 583 | qasigiannguit
# Processing Record 57 of Set 583 | milkovo
# Processing Record 58 of Set 583 | prince rupert
# Processing Record 59 of Set 583 | thompson
# Processing Record 60 of Set 583 | baglan
# Processing Record 61 of Set 583 | minas
# Processing Record 62 of Set 583 | lebu
# Processing Record 63 of Set 583 | hamilton
# Processing Record 64 of Set 583 | severo-kurilsk
# Processing Record 65 of Set 583 | kahului
# Processing Record 66 of Set 583 | caririacu
# Processing Record 67 of Set 583 | cockburn town
# Processing Record 68 of Set 583 | sitka
# Processing Record 69 of Set 583 | biak
# Processing Record 70 of Set 583 | ariquemes
# Processing Record 71 of Set 583 | berlevag
# Processing Record 72 of Set 583 | portland
# Processing Record 73 of Set 583 | poum
# Processing Record 74 of Set 583 | port elizabeth
# Processing Record 75 of Set 583 | chagda
# Processing Record 76 of Set 583 | chuy
# Processing Record 77 of Set 583 | narsaq
# Processing Record 78 of Set 583 | mar del plata
# Processing Record 79 of Set 583 | sam roi yot
# Processing Record 80 of Set 583 | barrow
# Processing Record 81 of Set 583 | sao filipe
# Processing Record 82 of Set 583 | nelson bay
# Processing Record 83 of Set 583 | bluff
# Processing Record 84 of Set 583 | nome
# Processing Record 85 of Set 583 | barcelona
# Processing Record 86 of Set 583 | luis correia
# Processing Record 87 of Set 583 | lokosovo
# Processing Record 88 of Set 583 | makinsk
# Processing Record 89 of Set 583 | zhezkazgan
# Processing Record 90 of Set 583 | cherskiy
# Processing Record 91 of Set 583 | nouakchott
# Processing Record 92 of Set 583 | saint-philippe
# Processing Record 93 of Set 583 | henties bay
# Processing Record 94 of Set 583 | north platte
# Processing Record 95 of Set 583 | lavrentiya
# Processing Record 96 of Set 583 | bethel
# Processing Record 97 of Set 583 | yulara
# Processing Record 98 of Set 583 | yarkovo
# Processing Record 99 of Set 583 | ankang
# Processing Record 100 of Set 583 | san patricio
# Processing Record 101 of Set 583 | ponta do sol
# Processing Record 102 of Set 583 | tautira
# Processing Record 103 of Set 583 | hilo
# Processing Record 104 of Set 583 | atuona
# Processing Record 105 of Set 583 | saraland
# Processing Record 106 of Set 583 | jamestown
# Processing Record 107 of Set 583 | ibotirama
# Processing Record 108 of Set 583 | astoria
# Processing Record 109 of Set 583 | labutta
# Processing Record 110 of Set 583 | mayo
# Processing Record 111 of Set 583 | constitucion
# Processing Record 112 of Set 583 | umzimvubu
# Processing Record 113 of Set 583 | lagoa
# Processing Record 114 of Set 583 | tsihombe
# Processing Record 115 of Set 583 | luena
# Processing Record 116 of Set 583 | abu zabad
# Processing Record 117 of Set 583 | margate
# Processing Record 118 of Set 583 | butaritari
# Processing Record 119 of Set 583 | carnarvon
# Processing Record 120 of Set 583 | cochabamba
# Processing Record 121 of Set 583 | pekan
# Processing Record 122 of Set 583 | imbituba
# Processing Record 123 of Set 583 | tommot
# Processing Record 124 of Set 583 | anadyr
# Processing Record 125 of Set 583 | taoudenni
# Processing Record 126 of Set 583 | puerto ayora
# Processing Record 127 of Set 583 | chapais
# Processing Record 128 of Set 583 | tucupita
# Processing Record 129 of Set 583 | barentsburg
# Processing Record 130 of Set 583 | mys shmidta
# Processing Record 131 of Set 583 | hulan ergi
# Processing Record 132 of Set 583 | glogow
# Processing Record 133 of Set 583 | quatre cocos
# Processing Record 134 of Set 583 | teguldet
# Processing Record 135 of Set 583 | shubarkuduk
# Processing Record 136 of Set 583 | aldan
# Processing Record 137 of Set 583 | kampot
# Processing Record 138 of Set 583 | bukene
# Processing Record 139 of Set 583 | chatsu
# Processing Record 140 of Set 583 | torbay
# Processing Record 141 of Set 583 | praia da vitoria
# Processing Record 142 of Set 583 | east london
# Processing Record 143 of Set 583 | nanortalik
# Processing Record 144 of Set 583 | karratha
# Processing Record 145 of Set 583 | luderitz
# Processing Record 146 of Set 583 | port alfred
# Processing Record 147 of Set 583 | ilka
# Processing Record 148 of Set 583 | brae
# Processing Record 149 of Set 583 | provideniya
# Processing Record 150 of Set 583 | itacoatiara
# Processing Record 151 of Set 583 | grand river south east
# Processing Record 152 of Set 583 | wuwei
# Processing Record 153 of Set 583 | barra velha
# Processing Record 154 of Set 583 | salalah
# Processing Record 155 of Set 583 | manokwari
# Processing Record 156 of Set 583 | naze
# Processing Record 157 of Set 583 | trapani
# Processing Record 158 of Set 583 | scarborough
# Processing Record 159 of Set 583 | mount gambier
# Processing Record 160 of Set 583 | shimoda
# Processing Record 161 of Set 583 | yumen
# Processing Record 162 of Set 583 | aegviidu
# Processing Record 163 of Set 583 | dunedin
# Processing Record 164 of Set 583 | sorvag
# Processing Record 165 of Set 583 | fortuna
# Processing Record 166 of Set 583 | la ronge
# Processing Record 167 of Set 583 | port-cartier
# Processing Record 168 of Set 583 | caohai
# Processing Record 169 of Set 583 | lompoc
# Processing Record 170 of Set 583 | dikson
# Processing Record 171 of Set 583 | mareeba
# Processing Record 172 of Set 583 | nuevitas
# Processing Record 173 of Set 583 | yaan
# Processing Record 174 of Set 583 | santiago del estero
# Processing Record 175 of Set 583 | samusu
# Processing Record 176 of Set 583 | hithadhoo
# Processing Record 177 of Set 583 | nikolskoye
# Processing Record 178 of Set 583 | nanakuli
# Processing Record 179 of Set 583 | arman
# Processing Record 180 of Set 583 | mahebourg
# Processing Record 181 of Set 583 | shchelyayur
# Processing Record 182 of Set 583 | dien bien
# Processing Record 183 of Set 583 | maniitsoq
# Processing Record 184 of Set 583 | skegness
# Processing Record 185 of Set 583 | urulga
# Processing Record 186 of Set 583 | tagab
# Processing Record 187 of Set 583 | aklavik
# Processing Record 188 of Set 583 | bar harbor
# Processing Record 189 of Set 583 | deder
# Processing Record 190 of Set 583 | kununurra
# Processing Record 191 of Set 583 | sungaipenuh
# Processing Record 192 of Set 583 | kenai
# Processing Record 193 of Set 583 | bredasdorp
# Processing Record 194 of Set 583 | scottsburgh
# Processing Record 195 of Set 583 | esperance
# Processing Record 196 of Set 583 | novopavlovka
# Processing Record 197 of Set 583 | soe
# Processing Record 198 of Set 583 | vao
# Processing Record 199 of Set 583 | castro
# Processing Record 200 of Set 583 | tonekabon
# Processing Record 201 of Set 583 | vanavara
# Processing Record 202 of Set 583 | limulunga
# Processing Record 203 of Set 583 | codrington
# Processing Record 204 of Set 583 | ambon
# Processing Record 205 of Set 583 | holme
# Processing Record 206 of Set 583 | banda aceh
# Processing Record 207 of Set 583 | seymchan
# Processing Record 208 of Set 583 | waipawa
# Processing Record 209 of Set 583 | newark
# Processing Record 210 of Set 583 | arraial do cabo
# Processing Record 211 of Set 583 | sola
# Processing Record 212 of Set 583 | raha
# Processing Record 213 of Set 583 | ornskoldsvik
# Processing Record 214 of Set 583 | faanui
# Processing Record 215 of Set 583 | zhuanghe
# Processing Record 216 of Set 583 | los corrales de buelna
# Processing Record 217 of Set 583 | gulshat
# Processing Record 218 of Set 583 | bambous virieux
# Processing Record 219 of Set 583 | klaksvik
# Processing Record 220 of Set 583 | olinda
# Processing Record 221 of Set 583 | deputatskiy
# Processing Record 222 of Set 583 | ostrovnoy
# Processing Record 223 of Set 583 | ancud
# Processing Record 224 of Set 583 | dingle
# Processing Record 225 of Set 583 | hay river
# Processing Record 226 of Set 583 | dongsheng
# Processing Record 227 of Set 583 | kaitangata
# Processing Record 228 of Set 583 | amderma
# Processing Record 229 of Set 583 | cananea
# Processing Record 230 of Set 583 | san cristobal
# Processing Record 231 of Set 583 | sentyabrskiy
# Processing Record 232 of Set 583 | guerrero negro
# Processing Record 233 of Set 583 | goure
# Processing Record 234 of Set 583 | bhanpura
# Processing Record 235 of Set 583 | ixtapa
# Processing Record 236 of Set 583 | mulchen
# Processing Record 237 of Set 583 | qandala
# Processing Record 238 of Set 583 | vardo
# Processing Record 239 of Set 583 | tungkang
# Processing Record 240 of Set 583 | fort nelson
# Processing Record 241 of Set 583 | laguna
# Processing Record 242 of Set 583 | bollnas
# Processing Record 243 of Set 583 | falealupo
# Processing Record 244 of Set 583 | bitung
# Processing Record 245 of Set 583 | beringovskiy
# Processing Record 246 of Set 583 | bereda
# Processing Record 247 of Set 583 | turbat
# Processing Record 248 of Set 583 | kalabo
# Processing Record 249 of Set 583 | saldanha
# Processing Record 250 of Set 583 | lata
# Processing Record 251 of Set 583 | xaxim
# Processing Record 252 of Set 583 | vaitupu
# Processing Record 253 of Set 583 | kruisfontein
# Processing Record 254 of Set 583 | port hawkesbury
# Processing Record 255 of Set 583 | madison
# Processing Record 256 of Set 583 | touros
# Processing Record 257 of Set 583 | hobart
# Processing Record 258 of Set 583 | usinsk
# Processing Record 259 of Set 583 | wakkanai
# Processing Record 260 of Set 583 | namibe
# Processing Record 261 of Set 583 | shulan
# Processing Record 262 of Set 583 | egvekinot
# Processing Record 263 of Set 583 | karla
# Processing Record 264 of Set 583 | vestmanna
# Processing Record 265 of Set 583 | mishan
# Processing Record 266 of Set 583 | bam
# Processing Record 267 of Set 583 | avera
# Processing Record 268 of Set 583 | ahipara
# Processing Record 269 of Set 583 | tame
# Processing Record 270 of Set 583 | tambovka
# Processing Record 271 of Set 583 | marion
# Processing Record 272 of Set 583 | port lincoln
# Processing Record 273 of Set 583 | saint-georges
# Processing Record 274 of Set 583 | qaanaaq
# Processing Record 275 of Set 583 | saint anthony
# Processing Record 276 of Set 583 | eureka
# Processing Record 277 of Set 583 | iisalmi
# Processing Record 278 of Set 583 | kangaatsiaq
# Processing Record 279 of Set 583 | moranbah
# Processing Record 280 of Set 583 | terra nova
# Processing Record 281 of Set 583 | ferme-neuve
# Processing Record 282 of Set 583 | champerico
# Processing Record 283 of Set 583 | barabai
# Processing Record 284 of Set 583 | milotice
# Processing Record 285 of Set 583 | bathsheba
# Processing Record 286 of Set 583 | strelka
# Processing Record 287 of Set 583 | antalaha
# Processing Record 288 of Set 583 | carutapera
# Processing Record 289 of Set 583 | beloha
# Processing Record 290 of Set 583 | maumere
# Processing Record 291 of Set 583 | imeni poliny osipenko
# Processing Record 292 of Set 583 | otofuke
# Processing Record 293 of Set 583 | amaigbo
# Processing Record 294 of Set 583 | kirakira
# Processing Record 295 of Set 583 | tilichiki
# Processing Record 296 of Set 583 | elektrogorsk
# Processing Record 297 of Set 583 | flinders
# Processing Record 298 of Set 583 | tel aviv-yafo
# Processing Record 299 of Set 583 | college
# Processing Record 300 of Set 583 | yatou
# Processing Record 301 of Set 583 | vila franca do campo
# Processing Record 302 of Set 583 | iranshahr
# Processing Record 303 of Set 583 | qaqortoq
# Processing Record 304 of Set 583 | inhambane
# Processing Record 305 of Set 583 | chokurdakh
# Processing Record 306 of Set 583 | saleaula
# Processing Record 307 of Set 583 | gornoye loo
# Processing Record 308 of Set 583 | grindavik
# Processing Record 309 of Set 583 | vammala
# Processing Record 310 of Set 583 | axim
# Processing Record 311 of Set 583 | luwingu
# Processing Record 312 of Set 583 | vestmannaeyjar
# Processing Record 313 of Set 583 | rawson
# Processing Record 314 of Set 583 | vietri sul mare
# Processing Record 315 of Set 583 | green valley
# Processing Record 316 of Set 583 | kamariotissa
# Processing Record 317 of Set 583 | leningradskiy
# Processing Record 318 of Set 583 | mullaitivu
# Processing Record 319 of Set 583 | wilmington
# Processing Record 320 of Set 583 | talnakh
# Processing Record 321 of Set 583 | bubaque
# Processing Record 322 of Set 583 | ngong
# Processing Record 323 of Set 583 | luanda
# Processing Record 324 of Set 583 | barbar
# Processing Record 325 of Set 583 | pacifica
# Processing Record 326 of Set 583 | san quintin
# Processing Record 327 of Set 583 | kavaratti
# Processing Record 328 of Set 583 | marcona
# Processing Record 329 of Set 583 | le port
# Processing Record 330 of Set 583 | tabou
# Processing Record 331 of Set 583 | baruun-urt
# Processing Record 332 of Set 583 | puerto madryn
# Processing Record 333 of Set 583 | tonj
# Processing Record 334 of Set 583 | diban
# Processing Record 335 of Set 583 | diamantino
# Processing Record 336 of Set 583 | miandrivazo
# Processing Record 337 of Set 583 | platteville
# Processing Record 338 of Set 583 | kedrovyy
# Processing Record 339 of Set 583 | pozo colorado
# Processing Record 340 of Set 583 | pimenta bueno
# Processing Record 341 of Set 583 | tessalit
# Processing Record 342 of Set 583 | toliary
# Processing Record 343 of Set 583 | ishigaki
# Processing Record 344 of Set 583 | sur
# Processing Record 345 of Set 583 | ust-karsk
# Processing Record 346 of Set 583 | mildura
# Processing Record 347 of Set 583 | xai-xai
# Processing Record 348 of Set 583 | petropavlovsk-kamchatskiy
# Processing Record 349 of Set 583 | susanville
# Processing Record 350 of Set 583 | moindou
# Processing Record 351 of Set 583 | kayankulam
# Processing Record 352 of Set 583 | ondo
# Processing Record 353 of Set 583 | pangnirtung
# Processing Record 354 of Set 583 | turukhansk
# Processing Record 355 of Set 583 | hobyo
# Processing Record 356 of Set 583 | kulachi
# Processing Record 357 of Set 583 | havre-saint-pierre
# Processing Record 358 of Set 583 | vidisha
# Processing Record 359 of Set 583 | kemijarvi
# Processing Record 360 of Set 583 | siemiatycze
# Processing Record 361 of Set 583 | belaya gora
# Processing Record 362 of Set 583 | altay
# Processing Record 363 of Set 583 | guanica
# Processing Record 364 of Set 583 | jiexiu
# Processing Record 365 of Set 583 | huntsville
# Processing Record 366 of Set 583 | paamiut
# Processing Record 367 of Set 583 | gat
# Processing Record 368 of Set 583 | nynashamn
# Processing Record 369 of Set 583 | biryusinsk
# Processing Record 370 of Set 583 | kidal
# Processing Record 371 of Set 583 | colares
# Processing Record 372 of Set 583 | raga
# Processing Record 373 of Set 583 | zheshart
# Processing Record 374 of Set 583 | iqaluit
# Processing Record 375 of Set 583 | victoria
# Processing Record 376 of Set 583 | cap malheureux
# Processing Record 377 of Set 583 | gayny
# Processing Record 378 of Set 583 | srednekolymsk
# Processing Record 379 of Set 583 | meulaboh
# Processing Record 380 of Set 583 | richards bay
# Processing Record 381 of Set 583 | west milford
# Processing Record 382 of Set 583 | rocha
# Processing Record 383 of Set 583 | agadir
# Processing Record 384 of Set 583 | galle
# Processing Record 385 of Set 583 | itoman
# Processing Record 386 of Set 583 | trelew
# Processing Record 387 of Set 583 | loralai
# Processing Record 388 of Set 583 | klyuchi
# Processing Record 389 of Set 583 | kiama
# Processing Record 390 of Set 583 | warrnambool
# Processing Record 391 of Set 583 | bonavista
# Processing Record 392 of Set 583 | tura
# Processing Record 393 of Set 583 | matagami
# Processing Record 394 of Set 583 | cabo san lucas
# Processing Record 395 of Set 583 | dandong
# Processing Record 396 of Set 583 | linxia
# Processing Record 397 of Set 583 | ritchie
# Processing Record 398 of Set 583 | kodiak
# Processing Record 399 of Set 583 | zajecar
# Processing Record 400 of Set 583 | yunjinghong
# Processing Record 401 of Set 583 | tieling
# Processing Record 402 of Set 583 | comodoro rivadavia
# Processing Record 403 of Set 583 | kyra
# Processing Record 404 of Set 583 | languyan
# Processing Record 405 of Set 583 | hami
# Processing Record 406 of Set 583 | atar
# Processing Record 407 of Set 583 | maceio
# Processing Record 408 of Set 583 | faya
# Processing Record 409 of Set 583 | mercedes
# Processing Record 410 of Set 583 | katsuura
# Processing Record 411 of Set 583 | kaiyuan
# Processing Record 412 of Set 583 | ambilobe
# Processing Record 413 of Set 583 | kamenka
# Processing Record 414 of Set 583 | nordfjordeid
# Processing Record 415 of Set 583 | caconde
# Processing Record 416 of Set 583 | kannur
# Processing Record 417 of Set 583 | cayenne
# Processing Record 418 of Set 583 | ormara
# Processing Record 419 of Set 583 | vila velha
# Processing Record 420 of Set 583 | trinidad
# Processing Record 421 of Set 583 | sao jose da coroa grande
# Processing Record 422 of Set 583 | saint george
# Processing Record 423 of Set 583 | huarmey
# Processing Record 424 of Set 583 | lagdo
# Processing Record 425 of Set 583 | maragheh
# Processing Record 426 of Set 583 | kamphaeng phet
# Processing Record 427 of Set 583 | gizo
# Processing Record 428 of Set 583 | algarrobo
# Processing Record 429 of Set 583 | ondorhaan
# Processing Record 430 of Set 583 | puerto escondido
# Processing Record 431 of Set 583 | barcelos
# Processing Record 432 of Set 583 | rio grande
# Processing Record 433 of Set 583 | jiamusi
# Processing Record 434 of Set 583 | koumac
# Processing Record 435 of Set 583 | saint-leu
# Processing Record 436 of Set 583 | belyy yar
# Processing Record 437 of Set 583 | sasso marconi
# Processing Record 438 of Set 583 | bakchar
# Processing Record 439 of Set 583 | souillac
# Processing Record 440 of Set 583 | teknaf
# Processing Record 441 of Set 583 | ozgon
# Processing Record 442 of Set 583 | airai
# Processing Record 443 of Set 583 | talcahuano
# Processing Record 444 of Set 583 | nuuk
# Processing Record 445 of Set 583 | moundou
# Processing Record 446 of Set 583 | hays
# Processing Record 447 of Set 583 | zeya
# Processing Record 448 of Set 583 | kijang
# Processing Record 449 of Set 583 | skjold
# Processing Record 450 of Set 583 | kargil
# Processing Record 451 of Set 583 | serpa
# Processing Record 452 of Set 583 | hyderabad
# Processing Record 453 of Set 583 | alofi
# Processing Record 454 of Set 583 | port hedland
# Processing Record 455 of Set 583 | willowmore
# Processing Record 456 of Set 583 | komsomolets
# Processing Record 457 of Set 583 | erenhot
# Processing Record 458 of Set 583 | sisimiut
# Processing Record 459 of Set 583 | pamekasan
# Processing Record 460 of Set 583 | ulverstone
# Processing Record 461 of Set 583 | krutinka
# Processing Record 462 of Set 583 | araouane
# Processing Record 463 of Set 583 | magadan
# Processing Record 464 of Set 583 | sorong
# Processing Record 465 of Set 583 | marondera
# Processing Record 466 of Set 583 | verkh-usugli
# Processing Record 467 of Set 583 | haines junction
# Processing Record 468 of Set 583 | mashhad
# Processing Record 469 of Set 583 | dali
# Processing Record 470 of Set 583 | pangai
# Processing Record 471 of Set 583 | lasa
# Processing Record 472 of Set 583 | reshetylivka
# Processing Record 473 of Set 583 | lewistown
# Processing Record 474 of Set 583 | auki
# Processing Record 475 of Set 583 | makakilo city
# Processing Record 476 of Set 583 | mandalgovi
# Processing Record 477 of Set 583 | khrebtovaya
# Processing Record 478 of Set 583 | buchanan
# Processing Record 479 of Set 583 | raudeberg
# Processing Record 480 of Set 583 | caravelas
# Processing Record 481 of Set 583 | yanchukan
# Processing Record 482 of Set 583 | san lorenzo
# Processing Record 483 of Set 583 | cabedelo
# Processing Record 484 of Set 583 | sistranda
# Processing Record 485 of Set 583 | cascais
# Processing Record 486 of Set 583 | voyvozh
# Processing Record 487 of Set 583 | sarahan
# Processing Record 488 of Set 583 | buje
# Processing Record 489 of Set 583 | prince albert
# Processing Record 490 of Set 583 | sechura
# Processing Record 491 of Set 583 | yerbogachen
# Processing Record 492 of Set 583 | saint-pierre
# Processing Record 493 of Set 583 | kawambwa
# Processing Record 494 of Set 583 | eloy
# Processing Record 495 of Set 583 | sakakah
# Processing Record 496 of Set 583 | ketchikan
# Processing Record 497 of Set 583 | conde
# Processing Record 498 of Set 583 | adrar
# Processing Record 499 of Set 583 | nizhniy ingash
# Processing Record 500 of Set 583 | smithers
# Processing Record 501 of Set 583 | kulhudhuffushi
# Processing Record 502 of Set 583 | mergui
# Processing Record 503 of Set 583 | atasu
# Processing Record 504 of Set 583 | khovu-aksy
# Processing Record 505 of Set 583 | rodrigues alves
# Processing Record 506 of Set 583 | san jose
# Processing Record 507 of Set 583 | celestun
# Processing Record 508 of Set 583 | alekseyevka
# Processing Record 509 of Set 583 | port moresby
# Processing Record 510 of Set 583 | opuwo
# Processing Record 511 of Set 583 | algeciras
# Processing Record 512 of Set 583 | gatesville
# Processing Record 513 of Set 583 | tripoli
# Processing Record 514 of Set 583 | roald
# Processing Record 515 of Set 583 | skhisma
# Processing Record 516 of Set 583 | vrangel
# Processing Record 517 of Set 583 | khani
# Processing Record 518 of Set 583 | montrose
# Processing Record 519 of Set 583 | korla
# Processing Record 520 of Set 583 | batsfjord
# Processing Record 521 of Set 583 | yagodnoye
# Processing Record 522 of Set 583 | son la
# Processing Record 523 of Set 583 | aksha
# Processing Record 524 of Set 583 | hofn
# Processing Record 525 of Set 583 | peddapuram
# Processing Record 526 of Set 583 | manado
# Processing Record 527 of Set 583 | sampit
# Processing Record 528 of Set 583 | boyolangu
# Processing Record 529 of Set 583 | malazgirt
# Processing Record 530 of Set 583 | oktyabrskiy
# Processing Record 531 of Set 583 | coihaique
# Processing Record 532 of Set 583 | ucar
# Processing Record 533 of Set 583 | tari
# Processing Record 534 of Set 583 | ndele
# Processing Record 535 of Set 583 | urucara
# Processing Record 536 of Set 583 | yeehaw junction
# Processing Record 537 of Set 583 | inuvik
# Processing Record 538 of Set 583 | tuatapere
# Processing Record 539 of Set 583 | zamora
# Processing Record 540 of Set 583 | angoche
# Processing Record 541 of Set 583 | mikuni
# Processing Record 542 of Set 583 | funtua
# Processing Record 543 of Set 583 | mutsamudu
# Processing Record 544 of Set 583 | sao joao da barra
# Processing Record 545 of Set 583 | shkotovo-22
# Processing Record 546 of Set 583 | ulaanbaatar
# Processing Record 547 of Set 583 | quimperle
# Processing Record 548 of Set 583 | moose factory
# Processing Record 549 of Set 583 | zverinogolovskoye
# Processing Record 550 of Set 583 | yarada
# Processing Record 551 of Set 583 | kloulklubed
# Processing Record 552 of Set 583 | berlin
# Processing Record 553 of Set 583 | kodinsk
# Processing Record 554 of Set 583 | the valley
# Processing Record 555 of Set 583 | goundam
# Processing Record 556 of Set 583 | malakal
# Processing Record 557 of Set 583 | oranjemund
# Processing Record 558 of Set 583 | cervo
# Processing Record 559 of Set 583 | caledonia
# Processing Record 560 of Set 583 | fevralsk
# Processing Record 561 of Set 583 | attawapiskat
# Processing Record 562 of Set 583 | broome
# Processing Record 563 of Set 583 | bilma
# Processing Record 564 of Set 583 | mkushi
# Processing Record 565 of Set 583 | porto novo
# Processing Record 566 of Set 583 | geraldton
# Processing Record 567 of Set 583 | mapiripan
# Processing Record 568 of Set 583 | warwick
# Processing Record 569 of Set 583 | karema
# Processing Record 570 of Set 583 | tazovskiy
# Processing Record 571 of Set 583 | yar-sale
# Processing Record 572 of Set 583 | kintampo
# Processing Record 573 of Set 583 | raymond
# Processing Record 574 of Set 583 | savelugu
# Processing Record 575 of Set 583 | biabou
# Processing Record 576 of Set 583 | kargasok
# Processing Record 577 of Set 583 | ijaki
# Processing Record 578 of Set 583 | hualmay
# Processing Record 579 of Set 583 | esmeraldas
# Processing Record 580 of Set 583 | gayeri
# Processing Record 581 of Set 583 | pindi bhattian
# Processing Record 582 of Set 583 | searcy
# 583

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#new loop on the city_results 
table_results = []

bad_results = []

#{"coord":{"lon":-70.9167,"lat":-53.15},"weather":[{"id":500,"main":"Rain","description":"light rain","icon":"10d"}],
#"base":"stations","main":{"temp":278.92,"feels_like":273.82,"temp_min":278.71,"temp_max":279.15,"pressure":993,"humidity":81},
#"visibility":10000,"wind":{"speed":9.77,"deg":300,"gust":14.92},"clouds":{"all":75},"dt":1618435659,
#"sys":{"type":1,"id":8487,"country":"CL","sunrise":1618399788,"sunset":1618437449},
#"timezone":-10800,"id":3874787,"name":"Punta Arenas","cod":200}


for result in city_results:
   #if "name" in result:
    if int(result["cod"]) == 200:     
        city_name = result["name"]
        city_latitude = result["coord"]["lat"]
        city_longitude = result["coord"]["lon"]
        city_maxtemp = result["main"]["temp_max"]
        city_humidity = result["main"]["humidity"]
        city_cloud = result["clouds"]["all"]
        city_wind = result["wind"]["speed"]
        city_country = result["sys"]["country"]
        city_date = result["dt"]
        #create a dictionary with the items
        city_dict = {
            "City": city_name, 
            "Lat": city_latitude, 
            "Lng": city_longitude, 
            "Max Temp": city_maxtemp, 
            "Humidity": city_humidity, 
            "Cloudiness": city_cloud, 
            "Wind Speed": city_wind, 
            "Country": city_country, 
            "Date": city_date
        }
        table_results.append(city_dict)
    
    else: 
        bad_results.append(result)
        
len(table_results)
#bad_results[0]

table_results_df = pd.DataFrame(table_results)
table_results_df
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Punta Arenas -53.1500  -70.9167     39.20        87           0
# 1         Fairbanks  64.8378 -147.7164     46.40        56          90
# 2             Kapaa  22.0752 -159.3190     78.80        57          20
# 3           Mataura -46.1927  168.8643     62.01        73          38
# 4          Coquimbo -29.9533  -71.3436     59.00        88          90
# ..              ...      ...       ...       ...       ...         ...
# 533         Hualmay -11.0964  -77.6139     66.56        85          86
# 534      Esmeraldas -19.7625  -44.3139     68.00        68           0
# 535          Gayéri  12.6497    0.4931     86.11        26          56
# 536  Pindi Bhattian  31.8978   73.2730     82.72        29          93
# 537          Searcy  35.2506  -91.7363     53.60        87           1
#
#      Wind Speed Country        Date
# 0         10.36      CL  1618453749
# 1          6.91      US  1618453479
# 2         16.11      US  1618453749
# 3          5.99      NZ  1618453750
# 4          1.14      CL  1618453463
# ..          ...     ...         ...
# 533        7.09      PE  1618453972
# 534       11.50      BR  1618453840
# 535        4.83      BF  1618453972
# 536       10.13      PK  1618453972
# 537        2.01      US  1618453973
#
# [538 rows x 9 columns]

# %%
#export to csv
table_results_df.to_csv('city_weather.csv')

# %%
#describe only works on numeric columns
table_results_df.describe()
#table_results_df.value_counts()
#table_results_df["Max Temp"].value_counts()
#table_results_df.info()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  538.000000  538.000000  538.000000  538.000000  538.000000  538.000000
# mean    21.619014   16.127382   57.629926   68.091078   52.459108    7.901989
# std     33.895367   90.498884   21.328226   23.254664   38.267013    5.730605
# min    -54.800000 -179.166700  -14.120000    6.000000    0.000000    0.250000
# 25%     -8.114325  -62.793350   42.090000   55.000000   15.000000    3.675000
# 50%     29.435250   18.974900   60.745000   73.500000   54.500000    6.540000
# 75%     50.543525   95.926925   75.480000   87.000000   90.000000   10.405000
# max     78.218600  179.316700   91.400000  100.000000  100.000000   38.990000
#
#                Date
# count  5.380000e+02
# mean   1.618454e+09
# std    9.039720e+01
# min    1.618453e+09
# 25%    1.618454e+09
# 50%    1.618454e+09
# 75%    1.618454e+09
# max    1.618454e+09

# %%
#homework example - don't run code
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  599.000000  599.000000  599.000000  599.000000  599.000000  599.000000
# mean    19.877028   19.568998   69.794808   69.353923   51.569282    7.979416
# std     33.262944   91.418472   15.678452   22.704698   35.405602    5.660694
# min    -54.800000 -179.170000   12.200000    7.000000    0.000000    0.360000
# 25%     -8.540000  -61.210000   59.000000   55.000000   20.000000    3.620000
# 50%     24.370000   24.670000   73.110000   75.000000   59.000000    6.730000
# 75%     46.585000  102.255000   80.600000   87.000000   85.000000   11.050000
# max     78.220000  179.320000  116.600000  100.000000  100.000000   42.500000
#
#                Date
# count  5.990000e+02
# mean   1.593605e+09
# std    5.738815e+01
# min    1.593605e+09
# 25%    1.593605e+09
# 50%    1.593605e+09
# 75%    1.593605e+09
# max    1.593605e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#homework example - don't run code
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  550.000000  550.000000  550.000000  550.000000  550.000000  550.000000
# mean    19.973545   17.124400   58.331400   67.890909   52.141818    8.544800
# std     33.284840   91.595451   25.795297   20.864881   35.766469    6.078869
# min    -54.800000 -179.170000  -11.340000    9.000000    0.000000    0.160000
# 25%     -8.077500  -64.627500   42.800000   55.000000   20.000000    4.525000
# 50%     23.630000   19.635000   64.940000   72.000000   57.000000    7.325000
# 75%     48.672500   97.350000   78.800000   83.000000   86.750000   11.410000
# max     78.220000  179.320000  102.200000  100.000000  100.000000   46.080000
#
#                Date
# count  5.500000e+02
# mean   1.585764e+09
# std    5.539674e+01
# min    1.585764e+09
# 25%    1.585764e+09
# 50%    1.585764e+09
# 75%    1.585764e+09
# max    1.585764e+09

# %%
#look for cities and humidity - check to see if there are any cities with humidity less than 100%
table_results_df.Humidity.value_counts()
# Out:
# 88    23
# 94    20
# 93    17
# 81    16
# 71    15
#       ..
# 35     1
# 24     1
# 44     1
# 41     1
# 6      1
# Name: Humidity, Length: 90, dtype: int64

# %%
#table_results_df.value_counts()
#table_results_df.info()

#Inspect the data and remove the cities where the humidity > 100%.
table_results_df[table_results_df.Humidity <= 100].describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  538.000000  538.000000  538.000000  538.000000  538.000000  538.000000
# mean    21.619014   16.127382   57.629926   68.091078   52.459108    7.901989
# std     33.895367   90.498884   21.328226   23.254664   38.267013    5.730605
# min    -54.800000 -179.166700  -14.120000    6.000000    0.000000    0.250000
# 25%     -8.114325  -62.793350   42.090000   55.000000   15.000000    3.675000
# 50%     29.435250   18.974900   60.745000   73.500000   54.500000    6.540000
# 75%     50.543525   95.926925   75.480000   87.000000   90.000000   10.405000
# max     78.218600  179.316700   91.400000  100.000000  100.000000   38.990000
#
#                Date
# count  5.380000e+02
# mean   1.618454e+09
# std    9.039720e+01
# min    1.618453e+09
# 25%    1.618454e+09
# 50%    1.618454e+09
# 75%    1.618454e+09
# max    1.618454e+09

# %%
#  Get the indices of cities that have humidity over 100%.
#table_results_df.Humidity.index
table_results_df[table_results_df.Humidity >= 100].index
# Out:
# Int64Index([9, 100, 125, 171, 195, 199, 235, 323, 445, 459, 506], dtype='int64')

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
#DON'T RUN THIS CODE - HOMEWORK EXAMPLE
# Out:
#           City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   butaritari   3.07  172.79     83.32        74          84       10.42
# 1  yerbogachen  61.28  108.01     79.52        58          20        7.70
# 2    cape town -33.93   18.42     73.00        77          27        4.70
# 3        touba   8.28   -7.68     79.97        75          82        3.58
# 4    jamestown  42.10  -79.24     64.00        88           1        6.93
#
#   Country        Date
# 0      KI  1593605283
# 1      RU  1593605121
# 2      ZA  1593605039
# 3      CI  1593605284
# 4      US  1593605284

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

#no_outliers_df = table_results_df(np.random.randn(538, 3))
#no_outliers_df
                              
#table_results_df[(np.abs(stats.zscore(table_results_df.Humidity)) < 3)]
#z_scipy = stats.zscore(table_results_df.Humidity)
#z_scipy
    
quartiles = table_results_df.Humidity.quantile([.25,.5,.75])
lowerq = quartiles[0.25]
upperq = quartiles[0.75]
iqr = upperq-lowerq

print(f"The lower quartile of humidity is: {lowerq}")
print(f"The upper quartile of humidity is: {upperq}")
print(f"The interquartile range of humidity is: {iqr}")
print(f"The the median of humidity is: {quartiles[0.5]} ")

lower_bound = lowerq - (1.5*iqr)
upper_bound = upperq + (1.5*iqr)
print(f"Values below {lower_bound} could be outliers.")
print(f"Values above {upper_bound} could be outliers.")

#outlier_humidity = table_results_df.loc[(table_results_df.Humidity < lower_bound) | (table_results_df.Humidity > upper_bound)]
#outlier_humidity
# Out:
# The lower quartile of humidity is: 55.0
# The upper quartile of humidity is: 87.0
# The interquartile range of humidity is: 32.0
# The the median of humidity is: 73.5
# Values below 7.0 could be outliers.
# Values above 135.0 could be outliers.

# %%
no_outliers_df = table_results_df[(table_results_df.Humidity > lower_bound) & (table_results_df.Humidity < upper_bound)]
no_outliers_df
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Punta Arenas -53.1500  -70.9167     39.20        87           0
# 1         Fairbanks  64.8378 -147.7164     46.40        56          90
# 2             Kapaa  22.0752 -159.3190     78.80        57          20
# 3           Mataura -46.1927  168.8643     62.01        73          38
# 4          Coquimbo -29.9533  -71.3436     59.00        88          90
# ..              ...      ...       ...       ...       ...         ...
# 533         Hualmay -11.0964  -77.6139     66.56        85          86
# 534      Esmeraldas -19.7625  -44.3139     68.00        68           0
# 535          Gayéri  12.6497    0.4931     86.11        26          56
# 536  Pindi Bhattian  31.8978   73.2730     82.72        29          93
# 537          Searcy  35.2506  -91.7363     53.60        87           1
#
#      Wind Speed Country        Date
# 0         10.36      CL  1618453749
# 1          6.91      US  1618453479
# 2         16.11      US  1618453749
# 3          5.99      NZ  1618453750
# 4          1.14      CL  1618453463
# ..          ...     ...         ...
# 533        7.09      PE  1618453972
# 534       11.50      BR  1618453840
# 535        4.83      BF  1618453972
# 536       10.13      PK  1618453972
# 537        2.01      US  1618453973
#
# [536 rows x 9 columns]

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
#homework example

# %%
plt.scatter(table_results_df.Lat, table_results_df["Max Temp"], marker="o", color="steelblue") #4472C4
plt.title("City Latitude vs. Max Tempature (04/14/2021)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid(True)

# Save the figure
plt.savefig("Latitude_Weather.png")
plt.show()

# %% [markdown]
# # Latitude vs. Temperature Analytics
# Shows strong, non-linear correlation between latitude and max tempatures.
# Cities with latitudes between -20 & 20 have the hottest weather, these cities are closest to the equator.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
#homework example

# %%
plt.scatter(table_results_df.Lat, table_results_df.Humidity, marker="o", color="r")
plt.title("City Latitude vs. Humidity (04/14/2021)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(True)

# Save the figure
plt.savefig("Latitude_Humidity.png")
plt.show()

# %% [markdown]
# # Latitude vs. Humidity Analytics
# Shows no correlation between latitude and humidity %.
# Cities all over the globe can have high or low humidity regardless of latitude

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(table_results_df.Lat, table_results_df.Cloudiness, marker="o", color="dimgray")
plt.title("City Latitude vs. Cloudiness (04/14/2021)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(True)

# Save the figure
plt.savefig("Latitude_Cloud.png")
plt.show()

# %% [markdown]
# # Latitude vs. Cloudiness Analytics
# Shows no correlation between latitude and cloudiness %. Cities all over the globe can have high or low cloudiness regardless of latitude.

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
#homework example

# %%
plt.scatter(table_results_df.Lat, table_results_df["Wind Speed"], marker="o", color="deepskyblue")
plt.title("City Latitude vs. Wind Speed (04/14/2021)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid(True)

# Save the figure
plt.savefig("Latitude_wind.png")
plt.show()

# %% [markdown]
# # Latitude vs. Wind Speed Analytics
# There is no correlation between latitude and wind speed. Cities all over the globe can have high or low wind speed regardless of latitude.

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#homework example
# Out:
# The r-value is: 0.46937863826630627

# %%
north_df = table_results_df[table_results_df.Lat >= 0]
north_df
correlation = round(stats.pearsonr(north_df.Lat,north_df["Max Temp"])[0],2)
print(f"The correlation between latitude and max temp is {correlation}")
# Out:
# The correlation between latitude and max temp is -0.9

# %%
slope, intercept, rvalue, pvalue, std_err = stats.linregress(north_df.Lat,north_df["Max Temp"])

print(f"Slope = {slope}")
print(f"Intercept = {intercept}")
print(f"Regress Value = {rvalue}")
print(f"Pvalue = {pvalue}")
print(f"Standard Deviation = {std_err}")
# Out:
# Slope = -1.0287968289196485
# Intercept = 93.76927056377221
# Regress Value = -0.8979366614988007
# Pvalue = 1.1831197176588629e-134
# Standard Deviation = 0.026144972293560362

# %%
# equation of line to calculate predicted weight
fit = slope * north_df.Lat + intercept
# Plot the linear model on top of scatter plot 
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(north_df.Lat, north_df["Max Temp"])
plt.plot(north_df.Lat,fit, "r-")
plt.title('Northern Hemisphere - Max Temp vs. Latitude Linear Regression')
plt.annotate(line_eq,(2,2), fontsize=15, color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp (F)')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.8062902480636118

# %%
#regression(xaxis,yaxis)
#def regression(x_values,y_values):
    #(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    #regress_values = x_values * slope + intercept
    #line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    #plt.plot(x_values,regress_values,"r-")
    #plt.scatter(x_values,y_values)

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#homework example
# Out:
# The r-value is: 0.6082708688906918

# %%
south_df = table_results_df[table_results_df.Lat <= 0]
south_df
correlation = round(stats.pearsonr(south_df.Lat,south_df["Max Temp"])[0],2)
print(f"The correlation between latitude and max temp is {correlation}")
# Out:
# The correlation between latitude and max temp is 0.63

# %%
slope, intercept, rvalue, pvalue, std_err = stats.linregress(south_df.Lat,south_df["Max Temp"])

print(f"Slope = {slope}")
print(f"Intercept = {intercept}")
print(f"Regress Value = {rvalue}")
print(f"Pvalue = {pvalue}")
print(f"Standard Deviation = {std_err}")
# Out:
# Slope = 0.4784423453221438
# Intercept = 81.0555918483034
# Regress Value = 0.6323039756625369
# Pvalue = 1.0794058828490426e-19
# Standard Deviation = 0.046056526074154766

# %%
# equation of line to calculate predicted weight
fit = slope * south_df.Lat + intercept
# Plot the linear model on top of scatter plot 
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(south_df.Lat, south_df["Max Temp"])
plt.plot(south_df.Lat,fit, "r-")
plt.title('Southern Hemisphere - Max Temp vs. Latitude Linear Regression')
plt.annotate(line_eq,(-55,80), fontsize=15, color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp (F)')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.3998083176386501

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#homework example
# Out:
# The r-value is: 0.000543987878808455

# %%
correlation = round(stats.pearsonr(north_df.Lat, north_df.Humidity)[0],2)
print(f"The correlation between latitude and humidity is {correlation}")
# Out:
# The correlation between latitude and humidity is 0.24

# %%
slope, intercept, rvalue, pvalue, std_err = stats.linregress(north_df.Lat,north_df.Humidity)

print(f"Slope = {slope}")
print(f"Intercept = {intercept}")
print(f"Regress Value = {rvalue}")
print(f"Pvalue = {pvalue}")
print(f"Standard Deviation = {std_err}")
# Out:
# Slope = 0.3022049628441326
# Intercept = 52.98648399888883
# Regress Value = 0.23979864302609294
# Pvalue = 2.7243830582544185e-06
# Standard Deviation = 0.06343417552291108

# %%
# equation of line to calculate predicted weight
fit = slope * north_df.Lat + intercept
# Plot the linear model on top of scatter plot 
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(north_df.Lat, north_df.Humidity)
plt.plot(north_df.Lat,fit, "r-")
plt.title('Northern Hemisphere - Humidity vs. Latitude Linear Regression')
plt.annotate(line_eq,(45,5), fontsize=15, color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.05750338919715555

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#homework example
# Out:
# The r-value is: 0.014985174297345524

# %%
correlation = round(stats.pearsonr(south_df.Lat, south_df.Humidity)[0],2)
print(f"The correlation between latitude and humidity is {correlation}")
# Out:
# The correlation between latitude and humidity is 0.23

# %%
slope, intercept, rvalue, pvalue, std_err = stats.linregress(south_df.Lat, south_df.Humidity)

print(f"Slope = {slope}")
print(f"Intercept = {intercept}")
print(f"Regress Value = {rvalue}")
print(f"Pvalue = {pvalue}")
print(f"Standard Deviation = {std_err}")
# Out:
# Slope = 0.3128799760713196
# Intercept = 81.33712559545225
# Regress Value = 0.22983925768330454
# Pvalue = 0.0030703541303243667
# Standard Deviation = 0.1040904573762244

# %%
# equation of line to calculate predicted weight
fit = slope * south_df.Lat + intercept
# Plot the linear model on top of scatter plot 
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(south_df.Lat, south_df.Humidity)
plt.plot(south_df.Lat,fit, "r-")
plt.title('Southern Hemisphere - Humidity vs. Latitude Linear Regression')
plt.annotate(line_eq,(-55,25), fontsize=15, color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.052826084372412464

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#homework example
# Out:
# The r-value is: 0.0020898727664228514

# %%
correlation = round(stats.pearsonr(north_df.Lat, north_df.Cloudiness)[0],2)
print(f"The correlation between latitude and humidity is {correlation}")
# Out:
# The correlation between latitude and humidity is 0.05

# %%
slope, intercept, rvalue, pvalue, std_err = stats.linregress(north_df.Lat,north_df.Cloudiness)

print(f"Slope = {slope}")
print(f"Intercept = {intercept}")
print(f"Regress Value = {rvalue}")
print(f"Pvalue = {pvalue}")
print(f"Standard Deviation = {std_err}")
# Out:
# Slope = 0.09757690069204276
# Intercept = 48.112329229287894
# Regress Value = 0.04896548664338679
# Pvalue = 0.34499378537676006
# Standard Deviation = 0.1031963206101318

# %%
# equation of line to calculate predicted weight
fit = slope * north_df.Lat + intercept
# Plot the linear model on top of scatter plot 
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(north_df.Lat, north_df.Cloudiness)
plt.plot(north_df.Lat,fit, "r-")
plt.title('Northern Hemisphere - Cloudiness vs. Latitude Linear Regression')
plt.annotate(line_eq,(45,5), fontsize=15, color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.00239761888222369

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#homework example
# Out:
# The r-value is: 0.0035263772085582894

# %%
correlation = round(stats.pearsonr(south_df.Lat, south_df.Cloudiness)[0],2)
print(f"The correlation between latitude and humidity is {correlation}")
# Out:
# The correlation between latitude and humidity is 0.25

# %%
slope, intercept, rvalue, pvalue, std_err = stats.linregress(south_df.Lat,south_df.Cloudiness)

print(f"Slope = {slope}")
print(f"Intercept = {intercept}")
print(f"Regress Value = {rvalue}")
print(f"Pvalue = {pvalue}")
print(f"Standard Deviation = {std_err}")
# Out:
# Slope = 0.6904460424468315
# Intercept = 68.38404581413646
# Regress Value = 0.25084189426839715
# Pvalue = 0.0011964289554980355
# Standard Deviation = 0.2093438063273361

# %%
# equation of line to calculate predicted weight
fit = slope * south_df.Lat + intercept
# Plot the linear model on top of scatter plot 
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(south_df.Lat, south_df.Cloudiness)
plt.plot(south_df.Lat,fit, "r-")
plt.title('Southern Hemisphere - Cloudiness vs. Latitude Linear Regression')
plt.annotate(line_eq,(-55,60), fontsize=15, color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.06292165592015773

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#homework example
# Out:
# The r-value is: 0.04019723576144484

# %%
correlation = round(stats.pearsonr(north_df.Lat, north_df["Wind Speed"])[0],2)
print(f"The correlation between latitude and wind speed is {correlation}")
# Out:
# The correlation between latitude and humidity is 0.17

# %%
slope, intercept, rvalue, pvalue, std_err = stats.linregress(north_df.Lat,north_df["Wind Speed"])

print(f"Slope = {slope}")
print(f"Intercept = {intercept}")
print(f"Regress Value = {rvalue}")
print(f"Pvalue = {pvalue}")
print(f"Standard Deviation = {std_err}")
# Out:
# Slope = 0.05311554835960756
# Intercept = 6.2344313201467365
# Regress Value = 0.17306550953722644
# Pvalue = 0.0007762677857017561
# Standard Deviation = 0.015672430773180035

# %%
# equation of line to calculate predicted weight
fit = slope * north_df.Lat + intercept
# Plot the linear model on top of scatter plot 
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(north_df.Lat, north_df["Wind Speed"])
plt.plot(north_df.Lat,fit, "r-")
plt.title('Northern Hemisphere - Wind Speed vs. Latitude Linear Regression')
plt.annotate(line_eq,(5,30), fontsize=15, color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.029951670591379813

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#homework example
# Out:
# The r-value is: 0.017128274759839232

# %%
correlation = round(stats.pearsonr(south_df.Lat, south_df["Wind Speed"])[0],2)
print(f"The correlation between latitude and wind speed is {correlation}")
# Out:
# The correlation between latitude and wind speed is -0.23

# %%
slope, intercept, rvalue, pvalue, std_err = stats.linregress(south_df.Lat,south_df["Wind Speed"])

print(f"Slope = {slope}")
print(f"Intercept = {intercept}")
print(f"Regress Value = {rvalue}")
print(f"Pvalue = {pvalue}")
print(f"Standard Deviation = {std_err}")
# Out:
# Slope = -0.08363214851396153
# Intercept = 4.954917996534512
# Regress Value = -0.22845146154943963
# Pvalue = 0.003258483952118045
# Standard Deviation = 0.028001573275766328

# %%
# equation of line to calculate predicted weight
fit = slope * south_df.Lat + intercept
# Plot the linear model on top of scatter plot 
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(south_df.Lat, south_df["Wind Speed"])
plt.plot(south_df.Lat,fit, "r-")
plt.title('Southern Hemisphere - Wind Speed vs. Latitude Linear Regression')
plt.annotate(line_eq,(-55,23), fontsize=15, color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.052190070284075095
